# %% [markdown]
# # Import packages
#
# import useful packages for experiments

# %%
import os
import argparse
import logging

import torch
from torch.optim.lr_scheduler import StepLR
import torchtext

from trainer.supervised_trainer import SupervisedTrainer
from models.encoderRNN import EncoderRNN
from models.decoderRNN import DecoderRNN
from models.seq2seq import Seq2seq
from loss.loss import Perplexity
from optim.optim import Optimizer
from dataset import fields
from evaluator.predictor import Predictor

import matplotlib.pyplot as plt
# Out:
# /home/hyeontae/hyeontae/venv/lib/python3.5/site-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# # Data load

# %%
train_path = "data/grammar_data_train.txt"
dev_path = "data/grammar_data_test.txt"
log_level = 'info'

# %% [markdown]
# # Log format

# %%
LOG_FORMAT = '%(asctime)s %(name)-12s %(levelname)-8s %(message)s'
logging.basicConfig(format=LOG_FORMAT, level=getattr(logging, log_level.upper()))

# %% [markdown]
# # Prepare dataset

# %%
src = fields.SourceField()
tgt = fields.TargetField()
max_len = 100
def len_filter(example):
    return len(example.src) <= max_len and len(example.tgt) <= max_len
train = torchtext.data.TabularDataset(
    path=train_path, format='tsv',
    fields=[('src', src), ('tgt', tgt)],
    filter_pred=len_filter
)
dev = torchtext.data.TabularDataset(
    path=dev_path, format='tsv',
    fields=[('src', src), ('tgt', tgt)],
    filter_pred=len_filter
)
src.build_vocab(train)
tgt.build_vocab(train)
input_vocab = src.vocab
output_vocab = tgt.vocab

# %% [markdown]
# # Prepare loss

# %%
weight = torch.ones(len(tgt.vocab))
pad = tgt.vocab.stoi[tgt.pad_token]
loss = Perplexity(weight, pad)
if torch.cuda.is_available():
    loss.cuda()
# Out:
# /home/hyeontae/hyeontae/venv/lib/python3.5/site-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# # Variable definition

# %%
seq2seq = None
optimizer = None

hidden_sizes = list(range(4, 50, 4))
print(hidden_sizes)
error_rate = []
accuracy = []
# Out:
# [4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48]

# %% [markdown]
# # Initialize model

# %%
for i in hidden_sizes:
    print("Hidden size is %d" % i)
    hidden_size = i
    bidirectional = True
    encoder = EncoderRNN(len(src.vocab), max_len, hidden_size,
                        bidirectional=bidirectional, variable_lengths=True)
    decoder = DecoderRNN(len(tgt.vocab), max_len, hidden_size * 2 if bidirectional else hidden_size,
                        dropout_p=0.2, use_attention=False, bidirectional=bidirectional,
                        eos_id=tgt.eos_id, sos_id=tgt.sos_id)
    seq2seq = Seq2seq(encoder, decoder)
    if torch.cuda.is_available():
        seq2seq.cuda()

    for param in seq2seq.parameters():
        param.data.uniform_(-0.08, 0.08)

    # train
    t = SupervisedTrainer(loss=loss, batch_size=32,
                        checkpoint_every=50,
                        print_every=100)

    seq2seq, ave_loss, character_accuracy = t.train(seq2seq, train,
                                                    num_epochs=10, dev_data=dev,
                                                    optimizer=optimizer,
                                                    teacher_forcing_ratio=0.5)

    error_rate.append(ave_loss/100)
    accuracy.append(character_accuracy)
# Out:
# /home/hyeontae/hyeontae/venv/lib/python3.5/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# 2019-01-15 16:49:06,627 trainer.supervised_trainer INFO     Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# Hidden size is 4
# 2019-01-15 16:49:11,485 trainer.supervised_trainer INFO     Progress: 2%, Train Error rate: 42.4469
# 2019-01-15 16:49:13,961 trainer.supervised_trainer INFO     Progress: 3%, Train Error rate: 12.0688
# 2019-01-15 16:49:16,294 trainer.supervised_trainer INFO     Progress: 4%, Train Error rate: 13.2778
# 2019-01-15 16:49:18,852 trainer.supervised_trainer INFO     Progress: 5%, Train Error rate: 14.1917
# 2019-01-15 16:49:21,023 trainer.supervised_trainer INFO     Progress: 6%, Train Error rate: 12.7163
# 2019-01-15 16:49:23,417 trainer.supervised_trainer INFO     Progress: 8%, Train Error rate: 12.3168
# 2019-01-15 16:49:25,713 trainer.supervised_trainer INFO     Progress: 9%, Train Error rate: 12.0674
# 2019-01-15 16:49:45,468 trainer.supervised_trainer INFO     Finished epoch 1: Train Error rate: 15.0281, Dev Error rate: 34.2284, Accuracy(Character): 0.1936, Accuracy(Word): 0.0000
# 2019-01-15 16:49:46,025 trainer.supervised_trainer INFO     Progress: 10%, Train Error rate: 15.0952
# 2019-01-15 16:49:48,437 trainer.supervised_trainer INFO     Progress: 11%, Train Error rate: 12.9408
# 2019-01-15 16:49:50,835 trainer.supervised_trainer INFO     Progress: 12%, Train Error rate: 13.2776
# 2019-01-15 16:49:53,424 trainer.supervised_trainer INFO     Progress: 13%, Train Error rate: 13.3890
# 2019-01-15 16:49:56,018 trainer.supervised_trainer INFO     Progress: 14%, Train Error rate: 10.7791
# 2019-01-15 16:49:58,420 trainer.supervised_trainer INFO     Progress: 16%, Train Error rate: 9.5417
# 2019-01-15 16:50:01,488 trainer.supervised_trainer INFO     Progress: 17%, Train Error rate: 12.4142
# 2019-01-15 16:50:03,469 trainer.supervised_trainer INFO     Progress: 18%, Train Error rate: 7.4457
# 2019-01-15 16:50:05,853 trainer.supervised_trainer INFO     Progress: 19%, Train Error rate: 8.3565
# 2019-01-15 16:50:24,752 trainer.supervised_trainer INFO     Finished epoch 2: Train Error rate: 10.8089, Dev Error rate: 14.8518, Accuracy(Character): 0.1474, Accuracy(Word): 0.0000
# 2019-01-15 16:50:26,343 trainer.supervised_trainer INFO     Progress: 20%, Train Error rate: 7.5353
# 2019-01-15 16:50:29,215 trainer.supervised_trainer INFO     Progress: 21%, Train Error rate: 7.3301
# 2019-01-15 16:50:31,465 trainer.supervised_trainer INFO     Progress: 22%, Train Error rate: 6.8934
# 2019-01-15 16:50:34,213 trainer.supervised_trainer INFO     Progress: 24%, Train Error rate: 7.2956
# 2019-01-15 16:50:36,812 trainer.supervised_trainer INFO     Progress: 25%, Train Error rate: 8.0544
# 2019-01-15 16:50:39,547 trainer.supervised_trainer INFO     Progress: 26%, Train Error rate: 7.1686
# 2019-01-15 16:50:42,033 trainer.supervised_trainer INFO     Progress: 27%, Train Error rate: 6.3601
# 2019-01-15 16:50:44,309 trainer.supervised_trainer INFO     Progress: 28%, Train Error rate: 6.0993
# 2019-01-15 16:50:46,701 trainer.supervised_trainer INFO     Progress: 29%, Train Error rate: 6.3795
# 2019-01-15 16:51:04,511 trainer.supervised_trainer INFO     Finished epoch 3: Train Error rate: 6.9248, Dev Error rate: 13.8602, Accuracy(Character): 0.2065, Accuracy(Word): 0.0001
# 2019-01-15 16:51:06,332 trainer.supervised_trainer INFO     Progress: 30%, Train Error rate: 5.8378
# 2019-01-15 16:51:08,598 trainer.supervised_trainer INFO     Progress: 32%, Train Error rate: 5.8015
# 2019-01-15 16:51:11,276 trainer.supervised_trainer INFO     Progress: 33%, Train Error rate: 6.3860
# 2019-01-15 16:51:13,597 trainer.supervised_trainer INFO     Progress: 34%, Train Error rate: 5.7839
# 2019-01-15 16:51:15,888 trainer.supervised_trainer INFO     Progress: 35%, Train Error rate: 5.6047
# 2019-01-15 16:51:18,207 trainer.supervised_trainer INFO     Progress: 36%, Train Error rate: 5.5764
# 2019-01-15 16:51:21,177 trainer.supervised_trainer INFO     Progress: 37%, Train Error rate: 8.0458
# 2019-01-15 16:51:23,517 trainer.supervised_trainer INFO     Progress: 38%, Train Error rate: 6.1157
# 2019-01-15 16:51:43,584 trainer.supervised_trainer INFO     Finished epoch 4: Train Error rate: 6.5120, Dev Error rate: 26.6133, Accuracy(Character): 0.2559, Accuracy(Word): 0.0342
# 2019-01-15 16:51:43,678 trainer.supervised_trainer INFO     Progress: 40%, Train Error rate: 8.7801
# 2019-01-15 16:51:45,996 trainer.supervised_trainer INFO     Progress: 41%, Train Error rate: 8.2782
# 2019-01-15 16:51:48,409 trainer.supervised_trainer INFO     Progress: 42%, Train Error rate: 27.9230
# 2019-01-15 16:51:51,022 trainer.supervised_trainer INFO     Progress: 43%, Train Error rate: 28.4074
# 2019-01-15 16:51:53,334 trainer.supervised_trainer INFO     Progress: 44%, Train Error rate: 7.6654
# 2019-01-15 16:51:55,783 trainer.supervised_trainer INFO     Progress: 45%, Train Error rate: 9.2470
# 2019-01-15 16:51:58,163 trainer.supervised_trainer INFO     Progress: 46%, Train Error rate: 8.4885
# 2019-01-15 16:52:00,444 trainer.supervised_trainer INFO     Progress: 48%, Train Error rate: 7.0998
# 2019-01-15 16:52:02,872 trainer.supervised_trainer INFO     Progress: 49%, Train Error rate: 7.8762
# 2019-01-15 16:52:21,921 trainer.supervised_trainer INFO     Finished epoch 5: Train Error rate: 12.6402, Dev Error rate: 21.8467, Accuracy(Character): 0.3900, Accuracy(Word): 0.0342
# 2019-01-15 16:52:22,614 trainer.supervised_trainer INFO     Progress: 50%, Train Error rate: 7.3797
# 2019-01-15 16:52:24,710 trainer.supervised_trainer INFO     Progress: 51%, Train Error rate: 5.3504
# 2019-01-15 16:52:27,539 trainer.supervised_trainer INFO     Progress: 52%, Train Error rate: 8.1498
# 2019-01-15 16:52:30,271 trainer.supervised_trainer INFO     Progress: 53%, Train Error rate: 5.8639
# 2019-01-15 16:52:33,700 trainer.supervised_trainer INFO     Progress: 54%, Train Error rate: 8.8020
# 2019-01-15 16:52:35,946 trainer.supervised_trainer INFO     Progress: 56%, Train Error rate: 4.5219
# 2019-01-15 16:52:38,310 trainer.supervised_trainer INFO     Progress: 57%, Train Error rate: 4.4180
# 2019-01-15 16:52:40,789 trainer.supervised_trainer INFO     Progress: 58%, Train Error rate: 4.8329
# 2019-01-15 16:52:42,828 trainer.supervised_trainer INFO     Progress: 59%, Train Error rate: 3.6616
# 2019-01-15 16:53:01,664 trainer.supervised_trainer INFO     Finished epoch 6: Train Error rate: 5.8098, Dev Error rate: 12.2596, Accuracy(Character): 0.4192, Accuracy(Word): 0.0342
# 2019-01-15 16:53:03,109 trainer.supervised_trainer INFO     Progress: 60%, Train Error rate: 5.6406
# 2019-01-15 16:53:05,886 trainer.supervised_trainer INFO     Progress: 61%, Train Error rate: 5.0667
# 2019-01-15 16:53:08,242 trainer.supervised_trainer INFO     Progress: 62%, Train Error rate: 4.4044
# 2019-01-15 16:53:10,518 trainer.supervised_trainer INFO     Progress: 64%, Train Error rate: 4.2786
# 2019-01-15 16:53:13,359 trainer.supervised_trainer INFO     Progress: 65%, Train Error rate: 5.8667
# 2019-01-15 16:53:15,870 trainer.supervised_trainer INFO     Progress: 66%, Train Error rate: 4.3294
# 2019-01-15 16:53:17,853 trainer.supervised_trainer INFO     Progress: 67%, Train Error rate: 3.3080
# 2019-01-15 16:53:20,206 trainer.supervised_trainer INFO     Progress: 68%, Train Error rate: 4.2081
# 2019-01-15 16:53:22,695 trainer.supervised_trainer INFO     Progress: 69%, Train Error rate: 4.0715
# 2019-01-15 16:53:40,684 trainer.supervised_trainer INFO     Finished epoch 7: Train Error rate: 4.4644, Dev Error rate: 12.7768, Accuracy(Character): 0.4190, Accuracy(Word): 0.0342
# 2019-01-15 16:53:42,753 trainer.supervised_trainer INFO     Progress: 70%, Train Error rate: 4.3052
# 2019-01-15 16:53:45,156 trainer.supervised_trainer INFO     Progress: 72%, Train Error rate: 4.2170
# 2019-01-15 16:53:47,625 trainer.supervised_trainer INFO     Progress: 73%, Train Error rate: 3.9047
# 2019-01-15 16:53:50,556 trainer.supervised_trainer INFO     Progress: 74%, Train Error rate: 5.2111
# 2019-01-15 16:53:52,991 trainer.supervised_trainer INFO     Progress: 75%, Train Error rate: 4.0652
# 2019-01-15 16:53:55,499 trainer.supervised_trainer INFO     Progress: 76%, Train Error rate: 4.3843
# 2019-01-15 16:53:58,093 trainer.supervised_trainer INFO     Progress: 77%, Train Error rate: 3.7114
# 2019-01-15 16:54:00,761 trainer.supervised_trainer INFO     Progress: 78%, Train Error rate: 4.4961
# 2019-01-15 16:54:21,159 trainer.supervised_trainer INFO     Finished epoch 8: Train Error rate: 4.2307, Dev Error rate: 11.4209, Accuracy(Character): 0.4149, Accuracy(Word): 0.0626
# 2019-01-15 16:54:21,373 trainer.supervised_trainer INFO     Progress: 80%, Train Error rate: 3.9088
# 2019-01-15 16:54:23,580 trainer.supervised_trainer INFO     Progress: 81%, Train Error rate: 2.9997
# 2019-01-15 16:54:26,393 trainer.supervised_trainer INFO     Progress: 82%, Train Error rate: 5.1628
# 2019-01-15 16:54:28,970 trainer.supervised_trainer INFO     Progress: 83%, Train Error rate: 4.9382
# 2019-01-15 16:54:31,258 trainer.supervised_trainer INFO     Progress: 84%, Train Error rate: 3.7836
# 2019-01-15 16:54:33,575 trainer.supervised_trainer INFO     Progress: 85%, Train Error rate: 4.4075
# 2019-01-15 16:54:36,167 trainer.supervised_trainer INFO     Progress: 86%, Train Error rate: 4.1263
# 2019-01-15 16:54:39,008 trainer.supervised_trainer INFO     Progress: 88%, Train Error rate: 4.6066
# 2019-01-15 16:54:41,296 trainer.supervised_trainer INFO     Progress: 89%, Train Error rate: 4.4282
# 2019-01-15 16:55:00,309 trainer.supervised_trainer INFO     Finished epoch 9: Train Error rate: 4.3144, Dev Error rate: 13.0603, Accuracy(Character): 0.4100, Accuracy(Word): 0.0626
# 2019-01-15 16:55:01,030 trainer.supervised_trainer INFO     Progress: 90%, Train Error rate: 3.9445
# 2019-01-15 16:55:03,098 trainer.supervised_trainer INFO     Progress: 91%, Train Error rate: 3.1839
# 2019-01-15 16:55:05,743 trainer.supervised_trainer INFO     Progress: 92%, Train Error rate: 5.0198
# 2019-01-15 16:55:08,234 trainer.supervised_trainer INFO     Progress: 93%, Train Error rate: 4.8815
# 2019-01-15 16:55:10,566 trainer.supervised_trainer INFO     Progress: 94%, Train Error rate: 3.9050
# 2019-01-15 16:55:13,094 trainer.supervised_trainer INFO     Progress: 96%, Train Error rate: 5.1683
# 2019-01-15 16:55:15,547 trainer.supervised_trainer INFO     Progress: 97%, Train Error rate: 4.4567
# 2019-01-15 16:55:18,057 trainer.supervised_trainer INFO     Progress: 98%, Train Error rate: 4.7562
# 2019-01-15 16:55:20,926 trainer.supervised_trainer INFO     Progress: 99%, Train Error rate: 6.5634
# 2019-01-15 16:55:39,344 trainer.supervised_trainer INFO     Finished epoch 10: Train Error rate: 4.6548, Dev Error rate: 11.9509, Accuracy(Character): 0.4121, Accuracy(Word): 0.0626
# 2019-01-15 16:55:39,348 trainer.supervised_trainer INFO     Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# Hidden size is 8
# 2019-01-15 16:55:44,250 trainer.supervised_trainer INFO     Progress: 2%, Train Error rate: 38.1465
# 2019-01-15 16:55:46,686 trainer.supervised_trainer INFO     Progress: 3%, Train Error rate: 14.9387
# 2019-01-15 16:55:49,091 trainer.supervised_trainer INFO     Progress: 4%, Train Error rate: 15.7788
# 2019-01-15 16:55:51,681 trainer.supervised_trainer INFO     Progress: 5%, Train Error rate: 16.2225
# 2019-01-15 16:55:53,879 trainer.supervised_trainer INFO     Progress: 6%, Train Error rate: 11.8742
# 2019-01-15 16:55:56,369 trainer.supervised_trainer INFO     Progress: 8%, Train Error rate: 13.3442
# 2019-01-15 16:55:58,878 trainer.supervised_trainer INFO     Progress: 9%, Train Error rate: 13.7775
# 2019-01-15 16:56:18,280 trainer.supervised_trainer INFO     Finished epoch 1: Train Error rate: 15.1946, Dev Error rate: 26.2395, Accuracy(Character): 0.1936, Accuracy(Word): 0.0000
# 2019-01-15 16:56:18,884 trainer.supervised_trainer INFO     Progress: 10%, Train Error rate: 11.1628
# 2019-01-15 16:56:21,383 trainer.supervised_trainer INFO     Progress: 11%, Train Error rate: 12.5620
# 2019-01-15 16:56:23,707 trainer.supervised_trainer INFO     Progress: 12%, Train Error rate: 10.6804
# 2019-01-15 16:56:26,015 trainer.supervised_trainer INFO     Progress: 13%, Train Error rate: 9.6394
# 2019-01-15 16:56:28,419 trainer.supervised_trainer INFO     Progress: 14%, Train Error rate: 11.0124
# 2019-01-15 16:56:30,817 trainer.supervised_trainer INFO     Progress: 16%, Train Error rate: 9.9216
# 2019-01-15 16:56:33,352 trainer.supervised_trainer INFO     Progress: 17%, Train Error rate: 8.8483
# 2019-01-15 16:56:35,908 trainer.supervised_trainer INFO     Progress: 18%, Train Error rate: 7.7258
# 2019-01-15 16:56:38,353 trainer.supervised_trainer INFO     Progress: 19%, Train Error rate: 6.8945
# 2019-01-15 16:56:57,600 trainer.supervised_trainer INFO     Finished epoch 2: Train Error rate: 9.5685, Dev Error rate: 20.2741, Accuracy(Character): 0.3469, Accuracy(Word): 0.0342
# 2019-01-15 16:56:58,974 trainer.supervised_trainer INFO     Progress: 20%, Train Error rate: 8.1271
# 2019-01-15 16:57:01,376 trainer.supervised_trainer INFO     Progress: 21%, Train Error rate: 5.6542
# 2019-01-15 16:57:03,131 trainer.supervised_trainer INFO     Progress: 22%, Train Error rate: 3.3889
# 2019-01-15 16:57:05,622 trainer.supervised_trainer INFO     Progress: 24%, Train Error rate: 5.5423
# 2019-01-15 16:57:08,092 trainer.supervised_trainer INFO     Progress: 25%, Train Error rate: 5.3781
# 2019-01-15 16:57:10,275 trainer.supervised_trainer INFO     Progress: 26%, Train Error rate: 4.0916
# 2019-01-15 16:57:12,805 trainer.supervised_trainer INFO     Progress: 27%, Train Error rate: 5.5101
# 2019-01-15 16:57:15,702 trainer.supervised_trainer INFO     Progress: 28%, Train Error rate: 4.9642
# 2019-01-15 16:57:18,577 trainer.supervised_trainer INFO     Progress: 29%, Train Error rate: 4.1900
# 2019-01-15 16:57:36,916 trainer.supervised_trainer INFO     Finished epoch 3: Train Error rate: 5.0038, Dev Error rate: 9.0967, Accuracy(Character): 0.4197, Accuracy(Word): 0.0342
# 2019-01-15 16:57:38,997 trainer.supervised_trainer INFO     Progress: 30%, Train Error rate: 3.6926
# 2019-01-15 16:57:41,710 trainer.supervised_trainer INFO     Progress: 32%, Train Error rate: 3.8420
# 2019-01-15 16:57:43,857 trainer.supervised_trainer INFO     Progress: 33%, Train Error rate: 3.3597
# 2019-01-15 16:57:46,479 trainer.supervised_trainer INFO     Progress: 34%, Train Error rate: 3.5016
# 2019-01-15 16:57:49,457 trainer.supervised_trainer INFO     Progress: 35%, Train Error rate: 3.8500
# 2019-01-15 16:57:51,582 trainer.supervised_trainer INFO     Progress: 36%, Train Error rate: 2.7204
# 2019-01-15 16:57:53,858 trainer.supervised_trainer INFO     Progress: 37%, Train Error rate: 3.2268
# 2019-01-15 16:57:56,293 trainer.supervised_trainer INFO     Progress: 38%, Train Error rate: 3.3600
# 2019-01-15 16:58:16,119 trainer.supervised_trainer INFO     Finished epoch 4: Train Error rate: 3.3960, Dev Error rate: 10.7194, Accuracy(Character): 0.4306, Accuracy(Word): 0.0342
# 2019-01-15 16:58:16,248 trainer.supervised_trainer INFO     Progress: 40%, Train Error rate: 3.0138
# 2019-01-15 16:58:18,843 trainer.supervised_trainer INFO     Progress: 41%, Train Error rate: 3.7439
# 2019-01-15 16:58:21,384 trainer.supervised_trainer INFO     Progress: 42%, Train Error rate: 3.4064
# 2019-01-15 16:58:23,943 trainer.supervised_trainer INFO     Progress: 43%, Train Error rate: 3.1626
# 2019-01-15 16:58:26,566 trainer.supervised_trainer INFO     Progress: 44%, Train Error rate: 3.0961
# 2019-01-15 16:58:28,836 trainer.supervised_trainer INFO     Progress: 45%, Train Error rate: 3.2455
# 2019-01-15 16:58:31,205 trainer.supervised_trainer INFO     Progress: 46%, Train Error rate: 3.1190
# 2019-01-15 16:58:33,590 trainer.supervised_trainer INFO     Progress: 48%, Train Error rate: 3.2821
# 2019-01-15 16:58:35,934 trainer.supervised_trainer INFO     Progress: 49%, Train Error rate: 3.1058
# 2019-01-15 16:58:54,885 trainer.supervised_trainer INFO     Finished epoch 5: Train Error rate: 3.2441, Dev Error rate: 8.0485, Accuracy(Character): 0.4552, Accuracy(Word): 0.0626
# 2019-01-15 16:58:55,547 trainer.supervised_trainer INFO     Progress: 50%, Train Error rate: 2.7754
# 2019-01-15 16:58:58,185 trainer.supervised_trainer INFO     Progress: 51%, Train Error rate: 3.2194
# 2019-01-15 16:59:00,682 trainer.supervised_trainer INFO     Progress: 52%, Train Error rate: 2.8780
# 2019-01-15 16:59:02,751 trainer.supervised_trainer INFO     Progress: 53%, Train Error rate: 2.6373
# 2019-01-15 16:59:05,407 trainer.supervised_trainer INFO     Progress: 54%, Train Error rate: 3.4980
# 2019-01-15 16:59:07,658 trainer.supervised_trainer INFO     Progress: 56%, Train Error rate: 2.6482
# 2019-01-15 16:59:10,184 trainer.supervised_trainer INFO     Progress: 57%, Train Error rate: 3.1630
# 2019-01-15 16:59:12,645 trainer.supervised_trainer INFO     Progress: 58%, Train Error rate: 2.9283
# 2019-01-15 16:59:15,668 trainer.supervised_trainer INFO     Progress: 59%, Train Error rate: 3.3027
# 2019-01-15 16:59:34,067 trainer.supervised_trainer INFO     Finished epoch 6: Train Error rate: 2.9859, Dev Error rate: 7.2475, Accuracy(Character): 0.4566, Accuracy(Word): 0.0626
# 2019-01-15 16:59:35,462 trainer.supervised_trainer INFO     Progress: 60%, Train Error rate: 2.6233
# 2019-01-15 16:59:38,061 trainer.supervised_trainer INFO     Progress: 61%, Train Error rate: 2.9882
# 2019-01-15 16:59:40,621 trainer.supervised_trainer INFO     Progress: 62%, Train Error rate: 2.5722
# 2019-01-15 16:59:42,728 trainer.supervised_trainer INFO     Progress: 64%, Train Error rate: 2.4269
# 2019-01-15 16:59:45,581 trainer.supervised_trainer INFO     Progress: 65%, Train Error rate: 3.4995
# 2019-01-15 16:59:47,581 trainer.supervised_trainer INFO     Progress: 66%, Train Error rate: 2.2905
# 2019-01-15 16:59:50,232 trainer.supervised_trainer INFO     Progress: 67%, Train Error rate: 3.3115
# 2019-01-15 16:59:52,519 trainer.supervised_trainer INFO     Progress: 68%, Train Error rate: 2.8401
# 2019-01-15 16:59:55,086 trainer.supervised_trainer INFO     Progress: 69%, Train Error rate: 3.1410
# 2019-01-15 17:00:13,108 trainer.supervised_trainer INFO     Finished epoch 7: Train Error rate: 2.8610, Dev Error rate: 8.6848, Accuracy(Character): 0.4732, Accuracy(Word): 0.0626
# 2019-01-15 17:00:15,270 trainer.supervised_trainer INFO     Progress: 70%, Train Error rate: 3.2131
# 2019-01-15 17:00:17,893 trainer.supervised_trainer INFO     Progress: 72%, Train Error rate: 3.2510
# 2019-01-15 17:00:20,196 trainer.supervised_trainer INFO     Progress: 73%, Train Error rate: 2.7075
# 2019-01-15 17:00:22,553 trainer.supervised_trainer INFO     Progress: 74%, Train Error rate: 2.9819
# 2019-01-15 17:00:24,912 trainer.supervised_trainer INFO     Progress: 75%, Train Error rate: 3.3014
# 2019-01-15 17:00:27,738 trainer.supervised_trainer INFO     Progress: 76%, Train Error rate: 3.9686
# 2019-01-15 17:00:29,944 trainer.supervised_trainer INFO     Progress: 77%, Train Error rate: 2.5364
# 2019-01-15 17:00:32,407 trainer.supervised_trainer INFO     Progress: 78%, Train Error rate: 3.0838
# 2019-01-15 17:00:52,149 trainer.supervised_trainer INFO     Finished epoch 8: Train Error rate: 3.1147, Dev Error rate: 7.0859, Accuracy(Character): 0.4765, Accuracy(Word): 0.0626
# 2019-01-15 17:00:52,512 trainer.supervised_trainer INFO     Progress: 80%, Train Error rate: 2.9850
# 2019-01-15 17:00:55,115 trainer.supervised_trainer INFO     Progress: 81%, Train Error rate: 2.9269
# 2019-01-15 17:00:57,467 trainer.supervised_trainer INFO     Progress: 82%, Train Error rate: 2.2304
# 2019-01-15 17:00:59,956 trainer.supervised_trainer INFO     Progress: 83%, Train Error rate: 2.3651
# 2019-01-15 17:01:03,038 trainer.supervised_trainer INFO     Progress: 84%, Train Error rate: 3.3214
# 2019-01-15 17:01:05,173 trainer.supervised_trainer INFO     Progress: 85%, Train Error rate: 2.1508
# 2019-01-15 17:01:07,497 trainer.supervised_trainer INFO     Progress: 86%, Train Error rate: 2.7982
# 2019-01-15 17:01:10,171 trainer.supervised_trainer INFO     Progress: 88%, Train Error rate: 2.9179
# 2019-01-15 17:01:12,281 trainer.supervised_trainer INFO     Progress: 89%, Train Error rate: 7.4113
# 2019-01-15 17:01:31,521 trainer.supervised_trainer INFO     Finished epoch 9: Train Error rate: 3.3574, Dev Error rate: 9.5437, Accuracy(Character): 0.4887, Accuracy(Word): 0.0626
# 2019-01-15 17:01:32,121 trainer.supervised_trainer INFO     Progress: 90%, Train Error rate: 3.4862
# 2019-01-15 17:01:34,518 trainer.supervised_trainer INFO     Progress: 91%, Train Error rate: 2.9070
# 2019-01-15 17:01:37,443 trainer.supervised_trainer INFO     Progress: 92%, Train Error rate: 3.4842
# 2019-01-15 17:01:39,324 trainer.supervised_trainer INFO     Progress: 93%, Train Error rate: 2.1933
# 2019-01-15 17:01:41,567 trainer.supervised_trainer INFO     Progress: 94%, Train Error rate: 2.7577
# 2019-01-15 17:01:43,887 trainer.supervised_trainer INFO     Progress: 96%, Train Error rate: 3.2540
# 2019-01-15 17:01:46,700 trainer.supervised_trainer INFO     Progress: 97%, Train Error rate: 2.6372
# 2019-01-15 17:01:48,937 trainer.supervised_trainer INFO     Progress: 98%, Train Error rate: 3.9040
# 2019-01-15 17:01:51,610 trainer.supervised_trainer INFO     Progress: 99%, Train Error rate: 2.9278
# 2019-01-15 17:02:10,310 trainer.supervised_trainer INFO     Finished epoch 10: Train Error rate: 2.9493, Dev Error rate: 5.7727, Accuracy(Character): 0.5012, Accuracy(Word): 0.0626
# 2019-01-15 17:02:10,316 trainer.supervised_trainer INFO     Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# Hidden size is 12
# 2019-01-15 17:02:15,002 trainer.supervised_trainer INFO     Progress: 2%, Train Error rate: 36.8066
# 2019-01-15 17:02:17,569 trainer.supervised_trainer INFO     Progress: 3%, Train Error rate: 12.4029
# 2019-01-15 17:02:19,928 trainer.supervised_trainer INFO     Progress: 4%, Train Error rate: 8.6197
# 2019-01-15 17:02:22,553 trainer.supervised_trainer INFO     Progress: 5%, Train Error rate: 8.4259
# 2019-01-15 17:02:25,082 trainer.supervised_trainer INFO     Progress: 6%, Train Error rate: 7.5011
# 2019-01-15 17:02:27,603 trainer.supervised_trainer INFO     Progress: 8%, Train Error rate: 7.9658
# 2019-01-15 17:02:29,911 trainer.supervised_trainer INFO     Progress: 9%, Train Error rate: 8.3892
# 2019-01-15 17:02:49,662 trainer.supervised_trainer INFO     Finished epoch 1: Train Error rate: 11.0627, Dev Error rate: 19.5558, Accuracy(Character): 0.2106, Accuracy(Word): 0.0342
# 2019-01-15 17:02:50,229 trainer.supervised_trainer INFO     Progress: 10%, Train Error rate: 8.5479
# 2019-01-15 17:02:53,187 trainer.supervised_trainer INFO     Progress: 11%, Train Error rate: 10.1282
# 2019-01-15 17:02:55,450 trainer.supervised_trainer INFO     Progress: 12%, Train Error rate: 6.6859
# 2019-01-15 17:02:57,743 trainer.supervised_trainer INFO     Progress: 13%, Train Error rate: 5.8828
# 2019-01-15 17:03:00,289 trainer.supervised_trainer INFO     Progress: 14%, Train Error rate: 6.5599
# 2019-01-15 17:03:02,711 trainer.supervised_trainer INFO     Progress: 16%, Train Error rate: 4.9585
# 2019-01-15 17:03:05,453 trainer.supervised_trainer INFO     Progress: 17%, Train Error rate: 6.0804
# 2019-01-15 17:03:08,040 trainer.supervised_trainer INFO     Progress: 18%, Train Error rate: 4.9324
# 2019-01-15 17:03:10,504 trainer.supervised_trainer INFO     Progress: 19%, Train Error rate: 4.4763
# 2019-01-15 17:03:29,041 trainer.supervised_trainer INFO     Finished epoch 2: Train Error rate: 6.1066, Dev Error rate: 13.5649, Accuracy(Character): 0.4592, Accuracy(Word): 0.0342
# 2019-01-15 17:03:30,337 trainer.supervised_trainer INFO     Progress: 20%, Train Error rate: 4.9612
# 2019-01-15 17:03:33,312 trainer.supervised_trainer INFO     Progress: 21%, Train Error rate: 4.4241
# 2019-01-15 17:03:35,702 trainer.supervised_trainer INFO     Progress: 22%, Train Error rate: 5.2541
# 2019-01-15 17:03:38,315 trainer.supervised_trainer INFO     Progress: 24%, Train Error rate: 4.6194
# 2019-01-15 17:03:40,476 trainer.supervised_trainer INFO     Progress: 25%, Train Error rate: 2.9211
# 2019-01-15 17:03:42,804 trainer.supervised_trainer INFO     Progress: 26%, Train Error rate: 4.0947
# 2019-01-15 17:03:45,149 trainer.supervised_trainer INFO     Progress: 27%, Train Error rate: 4.0758
# 2019-01-15 17:03:47,762 trainer.supervised_trainer INFO     Progress: 28%, Train Error rate: 4.4947
# 2019-01-15 17:03:49,820 trainer.supervised_trainer INFO     Progress: 29%, Train Error rate: 3.9654
# 2019-01-15 17:04:08,531 trainer.supervised_trainer INFO     Finished epoch 3: Train Error rate: 4.3043, Dev Error rate: 17.8456, Accuracy(Character): 0.4955, Accuracy(Word): 0.0626
# 2019-01-15 17:04:10,567 trainer.supervised_trainer INFO     Progress: 30%, Train Error rate: 5.2024
# 2019-01-15 17:04:13,122 trainer.supervised_trainer INFO     Progress: 32%, Train Error rate: 3.7874
# 2019-01-15 17:04:15,072 trainer.supervised_trainer INFO     Progress: 33%, Train Error rate: 2.5851
# 2019-01-15 17:04:17,658 trainer.supervised_trainer INFO     Progress: 34%, Train Error rate: 4.3279
# 2019-01-15 17:04:20,168 trainer.supervised_trainer INFO     Progress: 35%, Train Error rate: 4.7560
# 2019-01-15 17:04:22,711 trainer.supervised_trainer INFO     Progress: 36%, Train Error rate: 3.5882
# 2019-01-15 17:04:25,071 trainer.supervised_trainer INFO     Progress: 37%, Train Error rate: 3.5994
# 2019-01-15 17:04:27,543 trainer.supervised_trainer INFO     Progress: 38%, Train Error rate: 5.8501
# 2019-01-15 17:04:48,198 trainer.supervised_trainer INFO     Finished epoch 4: Train Error rate: 4.2737, Dev Error rate: 11.7937, Accuracy(Character): 0.5088, Accuracy(Word): 0.0626
# 2019-01-15 17:04:48,405 trainer.supervised_trainer INFO     Progress: 40%, Train Error rate: 4.4580
# 2019-01-15 17:04:50,955 trainer.supervised_trainer INFO     Progress: 41%, Train Error rate: 4.2333
# 2019-01-15 17:04:52,886 trainer.supervised_trainer INFO     Progress: 42%, Train Error rate: 2.5449
# 2019-01-15 17:04:55,272 trainer.supervised_trainer INFO     Progress: 43%, Train Error rate: 4.1738
# 2019-01-15 17:04:57,530 trainer.supervised_trainer INFO     Progress: 44%, Train Error rate: 5.9431
# 2019-01-15 17:04:59,796 trainer.supervised_trainer INFO     Progress: 45%, Train Error rate: 4.3873
# 2019-01-15 17:05:02,254 trainer.supervised_trainer INFO     Progress: 46%, Train Error rate: 5.9118
# 2019-01-15 17:05:04,872 trainer.supervised_trainer INFO     Progress: 48%, Train Error rate: 6.8286
# 2019-01-15 17:05:07,107 trainer.supervised_trainer INFO     Progress: 49%, Train Error rate: 3.0685
# 2019-01-15 17:05:26,387 trainer.supervised_trainer INFO     Finished epoch 5: Train Error rate: 4.5178, Dev Error rate: 17.9853, Accuracy(Character): 0.5539, Accuracy(Word): 0.0867
# 2019-01-15 17:05:27,358 trainer.supervised_trainer INFO     Progress: 50%, Train Error rate: 4.4854
# 2019-01-15 17:05:29,399 trainer.supervised_trainer INFO     Progress: 51%, Train Error rate: 2.2584
# 2019-01-15 17:05:31,831 trainer.supervised_trainer INFO     Progress: 52%, Train Error rate: 4.6468
# 2019-01-15 17:05:34,471 trainer.supervised_trainer INFO     Progress: 53%, Train Error rate: 3.9478
# 2019-01-15 17:05:36,362 trainer.supervised_trainer INFO     Progress: 54%, Train Error rate: 2.2202
# 2019-01-15 17:05:38,795 trainer.supervised_trainer INFO     Progress: 56%, Train Error rate: 3.1884
# 2019-01-15 17:05:40,939 trainer.supervised_trainer INFO     Progress: 57%, Train Error rate: 2.9693
# 2019-01-15 17:05:43,133 trainer.supervised_trainer INFO     Progress: 58%, Train Error rate: 3.0706
# 2019-01-15 17:05:46,083 trainer.supervised_trainer INFO     Progress: 59%, Train Error rate: 4.5957
# 2019-01-15 17:06:04,464 trainer.supervised_trainer INFO     Finished epoch 6: Train Error rate: 3.4465, Dev Error rate: 5.5560, Accuracy(Character): 0.5551, Accuracy(Word): 0.0867
# 2019-01-15 17:06:05,891 trainer.supervised_trainer INFO     Progress: 60%, Train Error rate: 2.7590
# 2019-01-15 17:06:07,933 trainer.supervised_trainer INFO     Progress: 61%, Train Error rate: 2.5376
# 2019-01-15 17:06:10,729 trainer.supervised_trainer INFO     Progress: 62%, Train Error rate: 3.9287
# 2019-01-15 17:06:12,885 trainer.supervised_trainer INFO     Progress: 64%, Train Error rate: 2.3927
# 2019-01-15 17:06:15,135 trainer.supervised_trainer INFO     Progress: 65%, Train Error rate: 2.5803
# 2019-01-15 17:06:17,528 trainer.supervised_trainer INFO     Progress: 66%, Train Error rate: 2.8039
# 2019-01-15 17:06:20,059 trainer.supervised_trainer INFO     Progress: 67%, Train Error rate: 3.1117
# 2019-01-15 17:06:22,275 trainer.supervised_trainer INFO     Progress: 68%, Train Error rate: 2.3503
# 2019-01-15 17:06:24,892 trainer.supervised_trainer INFO     Progress: 69%, Train Error rate: 2.6533
# 2019-01-15 17:06:42,744 trainer.supervised_trainer INFO     Finished epoch 7: Train Error rate: 2.8118, Dev Error rate: 5.4446, Accuracy(Character): 0.5865, Accuracy(Word): 0.0867
# 2019-01-15 17:06:44,570 trainer.supervised_trainer INFO     Progress: 70%, Train Error rate: 2.0905
# 2019-01-15 17:06:47,569 trainer.supervised_trainer INFO     Progress: 72%, Train Error rate: 3.2416
# 2019-01-15 17:06:50,072 trainer.supervised_trainer INFO     Progress: 73%, Train Error rate: 2.7299
# 2019-01-15 17:06:52,313 trainer.supervised_trainer INFO     Progress: 74%, Train Error rate: 2.1949
# 2019-01-15 17:06:54,892 trainer.supervised_trainer INFO     Progress: 75%, Train Error rate: 2.5950
# 2019-01-15 17:06:57,485 trainer.supervised_trainer INFO     Progress: 76%, Train Error rate: 2.2496
# 2019-01-15 17:07:00,305 trainer.supervised_trainer INFO     Progress: 77%, Train Error rate: 3.0270
# 2019-01-15 17:07:02,773 trainer.supervised_trainer INFO     Progress: 78%, Train Error rate: 1.9814
# 2019-01-15 17:07:22,459 trainer.supervised_trainer INFO     Finished epoch 8: Train Error rate: 2.5022, Dev Error rate: 6.3012, Accuracy(Character): 0.5803, Accuracy(Word): 0.0867
# 2019-01-15 17:07:22,597 trainer.supervised_trainer INFO     Progress: 80%, Train Error rate: 2.1473
# 2019-01-15 17:07:25,141 trainer.supervised_trainer INFO     Progress: 81%, Train Error rate: 2.3537
# 2019-01-15 17:07:27,593 trainer.supervised_trainer INFO     Progress: 82%, Train Error rate: 2.8580
# 2019-01-15 17:07:30,157 trainer.supervised_trainer INFO     Progress: 83%, Train Error rate: 2.7490
# 2019-01-15 17:07:32,621 trainer.supervised_trainer INFO     Progress: 84%, Train Error rate: 2.5583
# 2019-01-15 17:07:35,165 trainer.supervised_trainer INFO     Progress: 85%, Train Error rate: 2.2171
# 2019-01-15 17:07:37,614 trainer.supervised_trainer INFO     Progress: 86%, Train Error rate: 2.2432
# 2019-01-15 17:07:40,494 trainer.supervised_trainer INFO     Progress: 88%, Train Error rate: 2.8833
# 2019-01-15 17:07:43,053 trainer.supervised_trainer INFO     Progress: 89%, Train Error rate: 2.1523
# 2019-01-15 17:08:02,005 trainer.supervised_trainer INFO     Finished epoch 9: Train Error rate: 2.4764, Dev Error rate: 6.3240, Accuracy(Character): 0.5876, Accuracy(Word): 0.0867
# 2019-01-15 17:08:02,873 trainer.supervised_trainer INFO     Progress: 90%, Train Error rate: 2.2463
# 2019-01-15 17:08:05,565 trainer.supervised_trainer INFO     Progress: 91%, Train Error rate: 2.3961
# 2019-01-15 17:08:07,697 trainer.supervised_trainer INFO     Progress: 92%, Train Error rate: 1.8772
# 2019-01-15 17:08:09,924 trainer.supervised_trainer INFO     Progress: 93%, Train Error rate: 3.0695
# 2019-01-15 17:08:12,540 trainer.supervised_trainer INFO     Progress: 94%, Train Error rate: 3.0008
# 2019-01-15 17:08:14,916 trainer.supervised_trainer INFO     Progress: 96%, Train Error rate: 2.2983
# 2019-01-15 17:08:17,613 trainer.supervised_trainer INFO     Progress: 97%, Train Error rate: 2.5008
# 2019-01-15 17:08:20,235 trainer.supervised_trainer INFO     Progress: 98%, Train Error rate: 2.2518
# 2019-01-15 17:08:22,917 trainer.supervised_trainer INFO     Progress: 99%, Train Error rate: 2.3487
# 2019-01-15 17:08:41,601 trainer.supervised_trainer INFO     Finished epoch 10: Train Error rate: 2.4795, Dev Error rate: 6.2146, Accuracy(Character): 0.5968, Accuracy(Word): 0.0867
# 2019-01-15 17:08:41,605 trainer.supervised_trainer INFO     Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# Hidden size is 16
# 2019-01-15 17:08:46,391 trainer.supervised_trainer INFO     Progress: 2%, Train Error rate: 36.4695
# 2019-01-15 17:08:48,860 trainer.supervised_trainer INFO     Progress: 3%, Train Error rate: 14.2791
# 2019-01-15 17:08:51,470 trainer.supervised_trainer INFO     Progress: 4%, Train Error rate: 8.6664
# 2019-01-15 17:08:54,139 trainer.supervised_trainer INFO     Progress: 5%, Train Error rate: 7.0640
# 2019-01-15 17:08:56,759 trainer.supervised_trainer INFO     Progress: 6%, Train Error rate: 5.9001
# 2019-01-15 17:08:59,117 trainer.supervised_trainer INFO     Progress: 8%, Train Error rate: 5.3192
# 2019-01-15 17:09:01,797 trainer.supervised_trainer INFO     Progress: 9%, Train Error rate: 5.4745
# 2019-01-15 17:09:21,078 trainer.supervised_trainer INFO     Finished epoch 1: Train Error rate: 9.8642, Dev Error rate: 13.4185, Accuracy(Character): 0.4315, Accuracy(Word): 0.0342
# 2019-01-15 17:09:21,763 trainer.supervised_trainer INFO     Progress: 10%, Train Error rate: 4.4850
# 2019-01-15 17:09:23,646 trainer.supervised_trainer INFO     Progress: 11%, Train Error rate: 3.7041
# 2019-01-15 17:09:26,384 trainer.supervised_trainer INFO     Progress: 12%, Train Error rate: 4.5179
# 2019-01-15 17:09:28,936 trainer.supervised_trainer INFO     Progress: 13%, Train Error rate: 4.6850
# 2019-01-15 17:09:31,284 trainer.supervised_trainer INFO     Progress: 14%, Train Error rate: 4.0102
# 2019-01-15 17:09:33,685 trainer.supervised_trainer INFO     Progress: 16%, Train Error rate: 4.2085
# 2019-01-15 17:09:36,232 trainer.supervised_trainer INFO     Progress: 17%, Train Error rate: 3.9005
# 2019-01-15 17:09:38,581 trainer.supervised_trainer INFO     Progress: 18%, Train Error rate: 3.8669
# 2019-01-15 17:09:41,464 trainer.supervised_trainer INFO     Progress: 19%, Train Error rate: 4.1645
# 2019-01-15 17:10:00,346 trainer.supervised_trainer INFO     Finished epoch 2: Train Error rate: 4.1472, Dev Error rate: 9.8969, Accuracy(Character): 0.4464, Accuracy(Word): 0.0342
# 2019-01-15 17:10:01,771 trainer.supervised_trainer INFO     Progress: 20%, Train Error rate: 3.4383
# 2019-01-15 17:10:03,881 trainer.supervised_trainer INFO     Progress: 21%, Train Error rate: 2.7832
# 2019-01-15 17:10:06,131 trainer.supervised_trainer INFO     Progress: 22%, Train Error rate: 3.3546
# 2019-01-15 17:10:08,891 trainer.supervised_trainer INFO     Progress: 24%, Train Error rate: 3.7316
# 2019-01-15 17:10:11,750 trainer.supervised_trainer INFO     Progress: 25%, Train Error rate: 3.8305
# 2019-01-15 17:10:14,216 trainer.supervised_trainer INFO     Progress: 26%, Train Error rate: 2.6343
# 2019-01-15 17:10:17,019 trainer.supervised_trainer INFO     Progress: 27%, Train Error rate: 2.8991
# 2019-01-15 17:10:18,818 trainer.supervised_trainer INFO     Progress: 28%, Train Error rate: 1.7615
# 2019-01-15 17:10:21,304 trainer.supervised_trainer INFO     Progress: 29%, Train Error rate: 2.7259
# 2019-01-15 17:10:39,373 trainer.supervised_trainer INFO     Finished epoch 3: Train Error rate: 3.0290, Dev Error rate: 13.6977, Accuracy(Character): 0.4640, Accuracy(Word): 0.0626
# 2019-01-15 17:10:41,238 trainer.supervised_trainer INFO     Progress: 30%, Train Error rate: 3.5263
# 2019-01-15 17:10:43,988 trainer.supervised_trainer INFO     Progress: 32%, Train Error rate: 2.8709
# 2019-01-15 17:10:46,503 trainer.supervised_trainer INFO     Progress: 33%, Train Error rate: 2.9780
# 2019-01-15 17:10:48,954 trainer.supervised_trainer INFO     Progress: 34%, Train Error rate: 2.7368
# 2019-01-15 17:10:51,231 trainer.supervised_trainer INFO     Progress: 35%, Train Error rate: 2.4147
# 2019-01-15 17:10:53,535 trainer.supervised_trainer INFO     Progress: 36%, Train Error rate: 2.2295
# 2019-01-15 17:10:55,785 trainer.supervised_trainer INFO     Progress: 37%, Train Error rate: 4.1291
# 2019-01-15 17:10:58,434 trainer.supervised_trainer INFO     Progress: 38%, Train Error rate: 3.1408
# 2019-01-15 17:11:18,144 trainer.supervised_trainer INFO     Finished epoch 4: Train Error rate: 2.9205, Dev Error rate: 6.1077, Accuracy(Character): 0.4867, Accuracy(Word): 0.0626
# 2019-01-15 17:11:18,246 trainer.supervised_trainer INFO     Progress: 40%, Train Error rate: 2.6196
# 2019-01-15 17:11:20,578 trainer.supervised_trainer INFO     Progress: 41%, Train Error rate: 2.8549
# 2019-01-15 17:11:23,192 trainer.supervised_trainer INFO     Progress: 42%, Train Error rate: 2.8750
# 2019-01-15 17:11:25,377 trainer.supervised_trainer INFO     Progress: 43%, Train Error rate: 2.3352
# 2019-01-15 17:11:27,689 trainer.supervised_trainer INFO     Progress: 44%, Train Error rate: 3.2576
# 2019-01-15 17:11:30,314 trainer.supervised_trainer INFO     Progress: 45%, Train Error rate: 3.2740
# 2019-01-15 17:11:32,743 trainer.supervised_trainer INFO     Progress: 46%, Train Error rate: 3.5158
# 2019-01-15 17:11:34,891 trainer.supervised_trainer INFO     Progress: 48%, Train Error rate: 2.8878
# 2019-01-15 17:11:37,292 trainer.supervised_trainer INFO     Progress: 49%, Train Error rate: 2.8284
# 2019-01-15 17:11:56,471 trainer.supervised_trainer INFO     Finished epoch 5: Train Error rate: 2.9131, Dev Error rate: 5.4781, Accuracy(Character): 0.5014, Accuracy(Word): 0.0626
# 2019-01-15 17:11:57,313 trainer.supervised_trainer INFO     Progress: 50%, Train Error rate: 2.3410
# 2019-01-15 17:11:59,682 trainer.supervised_trainer INFO     Progress: 51%, Train Error rate: 2.0978
# 2019-01-15 17:12:02,126 trainer.supervised_trainer INFO     Progress: 52%, Train Error rate: 2.0142
# 2019-01-15 17:12:05,063 trainer.supervised_trainer INFO     Progress: 53%, Train Error rate: 2.8985
# 2019-01-15 17:12:07,570 trainer.supervised_trainer INFO     Progress: 54%, Train Error rate: 2.1970
# 2019-01-15 17:12:09,705 trainer.supervised_trainer INFO     Progress: 56%, Train Error rate: 2.1353
# 2019-01-15 17:12:11,910 trainer.supervised_trainer INFO     Progress: 57%, Train Error rate: 2.3777
# 2019-01-15 17:12:14,038 trainer.supervised_trainer INFO     Progress: 58%, Train Error rate: 3.8201
# 2019-01-15 17:12:16,614 trainer.supervised_trainer INFO     Progress: 59%, Train Error rate: 3.8941
# 2019-01-15 17:12:35,303 trainer.supervised_trainer INFO     Finished epoch 6: Train Error rate: 2.6724, Dev Error rate: 10.2826, Accuracy(Character): 0.5346, Accuracy(Word): 0.0626
# 2019-01-15 17:12:36,732 trainer.supervised_trainer INFO     Progress: 60%, Train Error rate: 2.3689
# 2019-01-15 17:12:38,991 trainer.supervised_trainer INFO     Progress: 61%, Train Error rate: 3.2654
# 2019-01-15 17:12:41,351 trainer.supervised_trainer INFO     Progress: 62%, Train Error rate: 2.2693
# 2019-01-15 17:12:43,899 trainer.supervised_trainer INFO     Progress: 64%, Train Error rate: 2.1869
# 2019-01-15 17:12:46,509 trainer.supervised_trainer INFO     Progress: 65%, Train Error rate: 2.0087
# 2019-01-15 17:12:48,878 trainer.supervised_trainer INFO     Progress: 66%, Train Error rate: 2.7154
# 2019-01-15 17:12:51,803 trainer.supervised_trainer INFO     Progress: 67%, Train Error rate: 4.0277
# 2019-01-15 17:12:54,279 trainer.supervised_trainer INFO     Progress: 68%, Train Error rate: 2.0319
# 2019-01-15 17:12:56,742 trainer.supervised_trainer INFO     Progress: 69%, Train Error rate: 2.5301
# 2019-01-15 17:13:14,510 trainer.supervised_trainer INFO     Finished epoch 7: Train Error rate: 2.5808, Dev Error rate: 4.5885, Accuracy(Character): 0.5713, Accuracy(Word): 0.0867
# 2019-01-15 17:13:16,430 trainer.supervised_trainer INFO     Progress: 70%, Train Error rate: 1.7638
# 2019-01-15 17:13:18,857 trainer.supervised_trainer INFO     Progress: 72%, Train Error rate: 2.6312
# 2019-01-15 17:13:21,354 trainer.supervised_trainer INFO     Progress: 73%, Train Error rate: 2.0988
# 2019-01-15 17:13:23,596 trainer.supervised_trainer INFO     Progress: 74%, Train Error rate: 2.0927
# 2019-01-15 17:13:26,263 trainer.supervised_trainer INFO     Progress: 75%, Train Error rate: 2.4737
# 2019-01-15 17:13:28,935 trainer.supervised_trainer INFO     Progress: 76%, Train Error rate: 2.1730
# 2019-01-15 17:13:31,317 trainer.supervised_trainer INFO     Progress: 77%, Train Error rate: 2.1230
# 2019-01-15 17:13:33,522 trainer.supervised_trainer INFO     Progress: 78%, Train Error rate: 1.8760
# 2019-01-15 17:13:53,341 trainer.supervised_trainer INFO     Finished epoch 8: Train Error rate: 2.2074, Dev Error rate: 4.3815, Accuracy(Character): 0.5727, Accuracy(Word): 0.0867
# 2019-01-15 17:13:53,708 trainer.supervised_trainer INFO     Progress: 80%, Train Error rate: 2.5856
# 2019-01-15 17:13:56,102 trainer.supervised_trainer INFO     Progress: 81%, Train Error rate: 2.0985
# 2019-01-15 17:13:58,385 trainer.supervised_trainer INFO     Progress: 82%, Train Error rate: 1.9074
# 2019-01-15 17:14:00,784 trainer.supervised_trainer INFO     Progress: 83%, Train Error rate: 2.2618
# 2019-01-15 17:14:02,890 trainer.supervised_trainer INFO     Progress: 84%, Train Error rate: 2.1794
# 2019-01-15 17:14:05,169 trainer.supervised_trainer INFO     Progress: 85%, Train Error rate: 2.2412
# 2019-01-15 17:14:07,537 trainer.supervised_trainer INFO     Progress: 86%, Train Error rate: 2.2035
# 2019-01-15 17:14:09,910 trainer.supervised_trainer INFO     Progress: 88%, Train Error rate: 1.9964
# 2019-01-15 17:14:12,179 trainer.supervised_trainer INFO     Progress: 89%, Train Error rate: 2.5200
# 2019-01-15 17:14:31,317 trainer.supervised_trainer INFO     Finished epoch 9: Train Error rate: 2.2295, Dev Error rate: 5.5712, Accuracy(Character): 0.5796, Accuracy(Word): 0.0867
# 2019-01-15 17:14:32,254 trainer.supervised_trainer INFO     Progress: 90%, Train Error rate: 2.6140
# 2019-01-15 17:14:34,519 trainer.supervised_trainer INFO     Progress: 91%, Train Error rate: 2.5829
# 2019-01-15 17:14:37,629 trainer.supervised_trainer INFO     Progress: 92%, Train Error rate: 2.6772
# 2019-01-15 17:14:39,526 trainer.supervised_trainer INFO     Progress: 93%, Train Error rate: 1.7513
# 2019-01-15 17:14:41,846 trainer.supervised_trainer INFO     Progress: 94%, Train Error rate: 2.0111
# 2019-01-15 17:14:43,916 trainer.supervised_trainer INFO     Progress: 96%, Train Error rate: 1.7006
# 2019-01-15 17:14:46,163 trainer.supervised_trainer INFO     Progress: 97%, Train Error rate: 2.6319
# 2019-01-15 17:14:48,622 trainer.supervised_trainer INFO     Progress: 98%, Train Error rate: 2.1229
# 2019-01-15 17:14:50,745 trainer.supervised_trainer INFO     Progress: 99%, Train Error rate: 2.6930
# 2019-01-15 17:15:09,325 trainer.supervised_trainer INFO     Finished epoch 10: Train Error rate: 2.2845, Dev Error rate: 5.4520, Accuracy(Character): 0.5745, Accuracy(Word): 0.0867
# 2019-01-15 17:15:09,332 trainer.supervised_trainer INFO     Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# Hidden size is 20
# 2019-01-15 17:15:14,221 trainer.supervised_trainer INFO     Progress: 2%, Train Error rate: 34.4767
# 2019-01-15 17:15:16,670 trainer.supervised_trainer INFO     Progress: 3%, Train Error rate: 7.9995
# 2019-01-15 17:15:19,186 trainer.supervised_trainer INFO     Progress: 4%, Train Error rate: 6.8731
# 2019-01-15 17:15:21,801 trainer.supervised_trainer INFO     Progress: 5%, Train Error rate: 6.4106
# 2019-01-15 17:15:24,163 trainer.supervised_trainer INFO     Progress: 6%, Train Error rate: 5.0024
# 2019-01-15 17:15:26,844 trainer.supervised_trainer INFO     Progress: 8%, Train Error rate: 5.2918
# 2019-01-15 17:15:28,997 trainer.supervised_trainer INFO     Progress: 9%, Train Error rate: 3.7183
# 2019-01-15 17:15:48,064 trainer.supervised_trainer INFO     Finished epoch 1: Train Error rate: 8.2768, Dev Error rate: 9.9136, Accuracy(Character): 0.4323, Accuracy(Word): 0.0342
# 2019-01-15 17:15:48,998 trainer.supervised_trainer INFO     Progress: 10%, Train Error rate: 4.0001
# 2019-01-15 17:15:51,202 trainer.supervised_trainer INFO     Progress: 11%, Train Error rate: 3.1375
# 2019-01-15 17:15:53,346 trainer.supervised_trainer INFO     Progress: 12%, Train Error rate: 3.0899
# 2019-01-15 17:15:55,871 trainer.supervised_trainer INFO     Progress: 13%, Train Error rate: 3.5702
# 2019-01-15 17:15:58,220 trainer.supervised_trainer INFO     Progress: 14%, Train Error rate: 3.1659
# 2019-01-15 17:16:00,814 trainer.supervised_trainer INFO     Progress: 16%, Train Error rate: 4.3258
# 2019-01-15 17:16:03,535 trainer.supervised_trainer INFO     Progress: 17%, Train Error rate: 4.9662
# 2019-01-15 17:16:05,707 trainer.supervised_trainer INFO     Progress: 18%, Train Error rate: 3.2844
# 2019-01-15 17:16:08,325 trainer.supervised_trainer INFO     Progress: 19%, Train Error rate: 6.0117
# 2019-01-15 17:16:26,713 trainer.supervised_trainer INFO     Finished epoch 2: Train Error rate: 4.0655, Dev Error rate: 18.5847, Accuracy(Character): 0.4784, Accuracy(Word): 0.0626
# 2019-01-15 17:16:28,160 trainer.supervised_trainer INFO     Progress: 20%, Train Error rate: 5.3326
# 2019-01-15 17:16:30,428 trainer.supervised_trainer INFO     Progress: 21%, Train Error rate: 4.3562
# 2019-01-15 17:16:32,777 trainer.supervised_trainer INFO     Progress: 22%, Train Error rate: 6.3820
# 2019-01-15 17:16:35,168 trainer.supervised_trainer INFO     Progress: 24%, Train Error rate: 5.9759
# 2019-01-15 17:16:36,980 trainer.supervised_trainer INFO     Progress: 25%, Train Error rate: 2.0688
# 2019-01-15 17:16:39,340 trainer.supervised_trainer INFO     Progress: 26%, Train Error rate: 5.3042
# 2019-01-15 17:16:41,462 trainer.supervised_trainer INFO     Progress: 27%, Train Error rate: 3.5630
# 2019-01-15 17:16:44,411 trainer.supervised_trainer INFO     Progress: 28%, Train Error rate: 5.1487
# 2019-01-15 17:16:46,806 trainer.supervised_trainer INFO     Progress: 29%, Train Error rate: 3.0520
# 2019-01-15 17:17:04,634 trainer.supervised_trainer INFO     Finished epoch 3: Train Error rate: 4.4917, Dev Error rate: 12.6880, Accuracy(Character): 0.4796, Accuracy(Word): 0.0626
# 2019-01-15 17:17:06,262 trainer.supervised_trainer INFO     Progress: 30%, Train Error rate: 3.0661
# 2019-01-15 17:17:08,366 trainer.supervised_trainer INFO     Progress: 32%, Train Error rate: 3.2083
# 2019-01-15 17:17:10,733 trainer.supervised_trainer INFO     Progress: 33%, Train Error rate: 3.3269
# 2019-01-15 17:17:13,247 trainer.supervised_trainer INFO     Progress: 34%, Train Error rate: 4.5889
# 2019-01-15 17:17:15,544 trainer.supervised_trainer INFO     Progress: 35%, Train Error rate: 3.4575
# 2019-01-15 17:17:18,123 trainer.supervised_trainer INFO     Progress: 36%, Train Error rate: 3.9288
# 2019-01-15 17:17:20,271 trainer.supervised_trainer INFO     Progress: 37%, Train Error rate: 2.4018
# 2019-01-15 17:17:23,064 trainer.supervised_trainer INFO     Progress: 38%, Train Error rate: 3.0786
# 2019-01-15 17:17:43,263 trainer.supervised_trainer INFO     Finished epoch 4: Train Error rate: 3.3176, Dev Error rate: 7.7023, Accuracy(Character): 0.5454, Accuracy(Word): 0.0867
# 2019-01-15 17:17:43,477 trainer.supervised_trainer INFO     Progress: 40%, Train Error rate: 2.7339
# 2019-01-15 17:17:45,638 trainer.supervised_trainer INFO     Progress: 41%, Train Error rate: 2.0988
# 2019-01-15 17:17:48,141 trainer.supervised_trainer INFO     Progress: 42%, Train Error rate: 2.7726
# 2019-01-15 17:17:50,656 trainer.supervised_trainer INFO     Progress: 43%, Train Error rate: 2.9266
# 2019-01-15 17:17:53,334 trainer.supervised_trainer INFO     Progress: 44%, Train Error rate: 2.8496
# 2019-01-15 17:17:55,700 trainer.supervised_trainer INFO     Progress: 45%, Train Error rate: 2.7412
# 2019-01-15 17:17:58,566 trainer.supervised_trainer INFO     Progress: 46%, Train Error rate: 3.1097
# 2019-01-15 17:18:00,963 trainer.supervised_trainer INFO     Progress: 48%, Train Error rate: 2.2608
# 2019-01-15 17:18:03,495 trainer.supervised_trainer INFO     Progress: 49%, Train Error rate: 2.6569
# ...
# 2019-01-15 17:57:35,812 trainer.supervised_trainer INFO     Progress: 50%, Train Error rate: 1.7415
# 2019-01-15 17:57:38,683 trainer.supervised_trainer INFO     Progress: 51%, Train Error rate: 2.0706
# 2019-01-15 17:57:41,091 trainer.supervised_trainer INFO     Progress: 52%, Train Error rate: 1.5924
# 2019-01-15 17:57:43,490 trainer.supervised_trainer INFO     Progress: 53%, Train Error rate: 1.7171
# 2019-01-15 17:57:45,976 trainer.supervised_trainer INFO     Progress: 54%, Train Error rate: 1.7194
# 2019-01-15 17:57:48,549 trainer.supervised_trainer INFO     Progress: 56%, Train Error rate: 1.7758
# 2019-01-15 17:57:50,743 trainer.supervised_trainer INFO     Progress: 57%, Train Error rate: 1.5231
# 2019-01-15 17:57:53,294 trainer.supervised_trainer INFO     Progress: 58%, Train Error rate: 1.8307
# 2019-01-15 17:57:55,929 trainer.supervised_trainer INFO     Progress: 59%, Train Error rate: 1.8260
# 2019-01-15 17:58:14,455 trainer.supervised_trainer INFO     Finished epoch 6: Train Error rate: 1.7404, Dev Error rate: 3.8532, Accuracy(Character): 0.6517, Accuracy(Word): 0.1077
# 2019-01-15 17:58:16,007 trainer.supervised_trainer INFO     Progress: 60%, Train Error rate: 1.6504
# 2019-01-15 17:58:18,613 trainer.supervised_trainer INFO     Progress: 61%, Train Error rate: 1.6231
# 2019-01-15 17:58:20,873 trainer.supervised_trainer INFO     Progress: 62%, Train Error rate: 1.5063
# 2019-01-15 17:58:23,675 trainer.supervised_trainer INFO     Progress: 64%, Train Error rate: 2.2171
# 2019-01-15 17:58:26,193 trainer.supervised_trainer INFO     Progress: 65%, Train Error rate: 1.6216
# 2019-01-15 17:58:28,242 trainer.supervised_trainer INFO     Progress: 66%, Train Error rate: 1.4773
# 2019-01-15 17:58:31,028 trainer.supervised_trainer INFO     Progress: 67%, Train Error rate: 1.7502
# 2019-01-15 17:58:33,030 trainer.supervised_trainer INFO     Progress: 68%, Train Error rate: 1.4979
# 2019-01-15 17:58:35,632 trainer.supervised_trainer INFO     Progress: 69%, Train Error rate: 1.6917
# 2019-01-15 17:58:53,460 trainer.supervised_trainer INFO     Finished epoch 7: Train Error rate: 1.6726, Dev Error rate: 3.4522, Accuracy(Character): 0.6662, Accuracy(Word): 0.1077
# 2019-01-15 17:58:55,772 trainer.supervised_trainer INFO     Progress: 70%, Train Error rate: 1.6356
# 2019-01-15 17:58:57,841 trainer.supervised_trainer INFO     Progress: 72%, Train Error rate: 1.4500
# 2019-01-15 17:59:00,196 trainer.supervised_trainer INFO     Progress: 73%, Train Error rate: 1.6508
# 2019-01-15 17:59:02,734 trainer.supervised_trainer INFO     Progress: 74%, Train Error rate: 1.6741
# 2019-01-15 17:59:04,839 trainer.supervised_trainer INFO     Progress: 75%, Train Error rate: 1.4895
# 2019-01-15 17:59:06,846 trainer.supervised_trainer INFO     Progress: 76%, Train Error rate: 1.4366
# 2019-01-15 17:59:09,608 trainer.supervised_trainer INFO     Progress: 77%, Train Error rate: 1.9376
# 2019-01-15 17:59:12,179 trainer.supervised_trainer INFO     Progress: 78%, Train Error rate: 1.6201
# 2019-01-15 17:59:32,414 trainer.supervised_trainer INFO     Finished epoch 8: Train Error rate: 1.6266, Dev Error rate: 2.9686, Accuracy(Character): 0.6810, Accuracy(Word): 0.1087
# 2019-01-15 17:59:32,632 trainer.supervised_trainer INFO     Progress: 80%, Train Error rate: 1.7028
# 2019-01-15 17:59:34,878 trainer.supervised_trainer INFO     Progress: 81%, Train Error rate: 1.5030
# 2019-01-15 17:59:37,429 trainer.supervised_trainer INFO     Progress: 82%, Train Error rate: 1.5979
# 2019-01-15 17:59:39,760 trainer.supervised_trainer INFO     Progress: 83%, Train Error rate: 1.4884
# 2019-01-15 17:59:42,449 trainer.supervised_trainer INFO     Progress: 84%, Train Error rate: 1.5617
# 2019-01-15 17:59:44,782 trainer.supervised_trainer INFO     Progress: 85%, Train Error rate: 1.5033
# 2019-01-15 17:59:47,288 trainer.supervised_trainer INFO     Progress: 86%, Train Error rate: 1.5789
# 2019-01-15 17:59:49,710 trainer.supervised_trainer INFO     Progress: 88%, Train Error rate: 1.5508
# 2019-01-15 17:59:52,014 trainer.supervised_trainer INFO     Progress: 89%, Train Error rate: 1.5360
# 2019-01-15 18:00:11,187 trainer.supervised_trainer INFO     Finished epoch 9: Train Error rate: 1.5506, Dev Error rate: 3.7574, Accuracy(Character): 0.6817, Accuracy(Word): 0.1260
# 2019-01-15 18:00:12,105 trainer.supervised_trainer INFO     Progress: 90%, Train Error rate: 1.6241
# 2019-01-15 18:00:14,700 trainer.supervised_trainer INFO     Progress: 91%, Train Error rate: 1.5737
# 2019-01-15 18:00:17,051 trainer.supervised_trainer INFO     Progress: 92%, Train Error rate: 1.5535
# 2019-01-15 18:00:19,890 trainer.supervised_trainer INFO     Progress: 93%, Train Error rate: 1.5943
# 2019-01-15 18:00:22,083 trainer.supervised_trainer INFO     Progress: 94%, Train Error rate: 1.4632
# 2019-01-15 18:00:24,490 trainer.supervised_trainer INFO     Progress: 96%, Train Error rate: 1.5467
# 2019-01-15 18:00:26,701 trainer.supervised_trainer INFO     Progress: 97%, Train Error rate: 1.4628
# 2019-01-15 18:00:28,981 trainer.supervised_trainer INFO     Progress: 98%, Train Error rate: 1.4598
# 2019-01-15 18:00:31,350 trainer.supervised_trainer INFO     Progress: 99%, Train Error rate: 1.5022
# 2019-01-15 18:00:49,921 trainer.supervised_trainer INFO     Finished epoch 10: Train Error rate: 1.5130, Dev Error rate: 3.2625, Accuracy(Character): 0.6885, Accuracy(Word): 0.1261
# 2019-01-15 18:00:49,929 trainer.supervised_trainer INFO     Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# Hidden size is 48
# 2019-01-15 18:00:54,727 trainer.supervised_trainer INFO     Progress: 2%, Train Error rate: 29.9419
# 2019-01-15 18:00:57,283 trainer.supervised_trainer INFO     Progress: 3%, Train Error rate: 5.5927
# 2019-01-15 18:00:59,519 trainer.supervised_trainer INFO     Progress: 4%, Train Error rate: 3.4672
# 2019-01-15 18:01:02,362 trainer.supervised_trainer INFO     Progress: 5%, Train Error rate: 3.4952
# 2019-01-15 18:01:04,890 trainer.supervised_trainer INFO     Progress: 6%, Train Error rate: 2.9576
# 2019-01-15 18:01:07,526 trainer.supervised_trainer INFO     Progress: 8%, Train Error rate: 2.6307
# 2019-01-15 18:01:09,973 trainer.supervised_trainer INFO     Progress: 9%, Train Error rate: 2.1937
# 2019-01-15 18:01:29,500 trainer.supervised_trainer INFO     Finished epoch 1: Train Error rate: 5.9640, Dev Error rate: 4.8940, Accuracy(Character): 0.5505, Accuracy(Word): 0.0867
# 2019-01-15 18:01:30,284 trainer.supervised_trainer INFO     Progress: 10%, Train Error rate: 2.4063
# 2019-01-15 18:01:33,037 trainer.supervised_trainer INFO     Progress: 11%, Train Error rate: 2.4374
# 2019-01-15 18:01:35,744 trainer.supervised_trainer INFO     Progress: 12%, Train Error rate: 2.5816
# 2019-01-15 18:01:38,015 trainer.supervised_trainer INFO     Progress: 13%, Train Error rate: 1.8774
# 2019-01-15 18:01:40,653 trainer.supervised_trainer INFO     Progress: 14%, Train Error rate: 2.3032
# 2019-01-15 18:01:42,929 trainer.supervised_trainer INFO     Progress: 16%, Train Error rate: 1.9397
# 2019-01-15 18:01:45,315 trainer.supervised_trainer INFO     Progress: 17%, Train Error rate: 2.0176
# 2019-01-15 18:01:47,791 trainer.supervised_trainer INFO     Progress: 18%, Train Error rate: 2.3472
# 2019-01-15 18:01:50,497 trainer.supervised_trainer INFO     Progress: 19%, Train Error rate: 2.1773
# 2019-01-15 18:02:09,140 trainer.supervised_trainer INFO     Finished epoch 2: Train Error rate: 2.2145, Dev Error rate: 5.2415, Accuracy(Character): 0.5996, Accuracy(Word): 0.0868
# 2019-01-15 18:02:10,406 trainer.supervised_trainer INFO     Progress: 20%, Train Error rate: 2.2451
# 2019-01-15 18:02:12,818 trainer.supervised_trainer INFO     Progress: 21%, Train Error rate: 1.9591
# 2019-01-15 18:02:15,277 trainer.supervised_trainer INFO     Progress: 22%, Train Error rate: 2.2394
# 2019-01-15 18:02:17,366 trainer.supervised_trainer INFO     Progress: 24%, Train Error rate: 1.7840
# 2019-01-15 18:02:20,353 trainer.supervised_trainer INFO     Progress: 25%, Train Error rate: 2.2041
# 2019-01-15 18:02:23,089 trainer.supervised_trainer INFO     Progress: 26%, Train Error rate: 2.1982
# 2019-01-15 18:02:25,712 trainer.supervised_trainer INFO     Progress: 27%, Train Error rate: 2.0173
# 2019-01-15 18:02:28,318 trainer.supervised_trainer INFO     Progress: 28%, Train Error rate: 1.9808
# 2019-01-15 18:02:30,771 trainer.supervised_trainer INFO     Progress: 29%, Train Error rate: 1.8602
# 2019-01-15 18:02:48,732 trainer.supervised_trainer INFO     Finished epoch 3: Train Error rate: 2.0359, Dev Error rate: 4.3562, Accuracy(Character): 0.6173, Accuracy(Word): 0.1076
# 2019-01-15 18:02:50,484 trainer.supervised_trainer INFO     Progress: 30%, Train Error rate: 1.7768
# 2019-01-15 18:02:53,379 trainer.supervised_trainer INFO     Progress: 32%, Train Error rate: 2.0550
# 2019-01-15 18:02:55,564 trainer.supervised_trainer INFO     Progress: 33%, Train Error rate: 1.5961
# 2019-01-15 18:02:58,266 trainer.supervised_trainer INFO     Progress: 34%, Train Error rate: 1.7805
# 2019-01-15 18:03:00,527 trainer.supervised_trainer INFO     Progress: 35%, Train Error rate: 1.6449
# 2019-01-15 18:03:02,982 trainer.supervised_trainer INFO     Progress: 36%, Train Error rate: 1.8452
# 2019-01-15 18:03:05,395 trainer.supervised_trainer INFO     Progress: 37%, Train Error rate: 1.8541
# 2019-01-15 18:03:07,419 trainer.supervised_trainer INFO     Progress: 38%, Train Error rate: 1.7263
# 2019-01-15 18:03:27,364 trainer.supervised_trainer INFO     Finished epoch 4: Train Error rate: 1.7917, Dev Error rate: 4.7755, Accuracy(Character): 0.6288, Accuracy(Word): 0.1076
# 2019-01-15 18:03:27,439 trainer.supervised_trainer INFO     Progress: 40%, Train Error rate: 1.8393
# 2019-01-15 18:03:29,977 trainer.supervised_trainer INFO     Progress: 41%, Train Error rate: 1.7968
# 2019-01-15 18:03:32,467 trainer.supervised_trainer INFO     Progress: 42%, Train Error rate: 1.8227
# 2019-01-15 18:03:34,879 trainer.supervised_trainer INFO     Progress: 43%, Train Error rate: 1.6727
# 2019-01-15 18:03:37,376 trainer.supervised_trainer INFO     Progress: 44%, Train Error rate: 1.7412
# 2019-01-15 18:03:40,023 trainer.supervised_trainer INFO     Progress: 45%, Train Error rate: 1.7798
# 2019-01-15 18:03:42,434 trainer.supervised_trainer INFO     Progress: 46%, Train Error rate: 1.6824
# 2019-01-15 18:03:45,129 trainer.supervised_trainer INFO     Progress: 48%, Train Error rate: 1.7654
# 2019-01-15 18:03:47,526 trainer.supervised_trainer INFO     Progress: 49%, Train Error rate: 1.7062
# 2019-01-15 18:04:06,838 trainer.supervised_trainer INFO     Finished epoch 5: Train Error rate: 1.7426, Dev Error rate: 4.1022, Accuracy(Character): 0.6415, Accuracy(Word): 0.1083
# 2019-01-15 18:04:07,600 trainer.supervised_trainer INFO     Progress: 50%, Train Error rate: 1.7796
# 2019-01-15 18:04:09,941 trainer.supervised_trainer INFO     Progress: 51%, Train Error rate: 1.5454
# 2019-01-15 18:04:12,815 trainer.supervised_trainer INFO     Progress: 52%, Train Error rate: 1.8532
# 2019-01-15 18:04:15,282 trainer.supervised_trainer INFO     Progress: 53%, Train Error rate: 1.6664
# 2019-01-15 18:04:17,663 trainer.supervised_trainer INFO     Progress: 54%, Train Error rate: 1.6304
# 2019-01-15 18:04:20,341 trainer.supervised_trainer INFO     Progress: 56%, Train Error rate: 1.7031
# 2019-01-15 18:04:22,698 trainer.supervised_trainer INFO     Progress: 57%, Train Error rate: 1.5536
# 2019-01-15 18:04:25,019 trainer.supervised_trainer INFO     Progress: 58%, Train Error rate: 1.6138
# 2019-01-15 18:04:27,432 trainer.supervised_trainer INFO     Progress: 59%, Train Error rate: 1.5445
# 2019-01-15 18:04:46,333 trainer.supervised_trainer INFO     Finished epoch 6: Train Error rate: 1.6590, Dev Error rate: 3.0768, Accuracy(Character): 0.6771, Accuracy(Word): 0.1262
# 2019-01-15 18:04:47,824 trainer.supervised_trainer INFO     Progress: 60%, Train Error rate: 1.7340
# 2019-01-15 18:04:50,089 trainer.supervised_trainer INFO     Progress: 61%, Train Error rate: 1.5426
# 2019-01-15 18:04:52,780 trainer.supervised_trainer INFO     Progress: 62%, Train Error rate: 1.7084
# 2019-01-15 18:04:55,486 trainer.supervised_trainer INFO     Progress: 64%, Train Error rate: 1.6755
# 2019-01-15 18:04:57,985 trainer.supervised_trainer INFO     Progress: 65%, Train Error rate: 1.6076
# 2019-01-15 18:05:00,081 trainer.supervised_trainer INFO     Progress: 66%, Train Error rate: 1.4708
# 2019-01-15 18:05:02,440 trainer.supervised_trainer INFO     Progress: 67%, Train Error rate: 1.6756
# 2019-01-15 18:05:05,445 trainer.supervised_trainer INFO     Progress: 68%, Train Error rate: 1.7679
# 2019-01-15 18:05:08,216 trainer.supervised_trainer INFO     Progress: 69%, Train Error rate: 1.6150
# 2019-01-15 18:05:25,968 trainer.supervised_trainer INFO     Finished epoch 7: Train Error rate: 1.6240, Dev Error rate: 2.9264, Accuracy(Character): 0.6833, Accuracy(Word): 0.1261
# 2019-01-15 18:05:27,781 trainer.supervised_trainer INFO     Progress: 70%, Train Error rate: 1.4133
# 2019-01-15 18:05:30,179 trainer.supervised_trainer INFO     Progress: 72%, Train Error rate: 1.5827
# 2019-01-15 18:05:32,719 trainer.supervised_trainer INFO     Progress: 73%, Train Error rate: 1.6234
# 2019-01-15 18:05:35,296 trainer.supervised_trainer INFO     Progress: 74%, Train Error rate: 1.7628
# 2019-01-15 18:05:38,093 trainer.supervised_trainer INFO     Progress: 75%, Train Error rate: 1.6590
# 2019-01-15 18:05:40,351 trainer.supervised_trainer INFO     Progress: 76%, Train Error rate: 1.5150
# 2019-01-15 18:05:42,951 trainer.supervised_trainer INFO     Progress: 77%, Train Error rate: 1.6766
# 2019-01-15 18:05:45,209 trainer.supervised_trainer INFO     Progress: 78%, Train Error rate: 1.5671
# 2019-01-15 18:06:05,176 trainer.supervised_trainer INFO     Finished epoch 8: Train Error rate: 1.6095, Dev Error rate: 3.6403, Accuracy(Character): 0.6727, Accuracy(Word): 0.1262
# 2019-01-15 18:06:05,579 trainer.supervised_trainer INFO     Progress: 80%, Train Error rate: 1.6798
# 2019-01-15 18:06:08,062 trainer.supervised_trainer INFO     Progress: 81%, Train Error rate: 1.5580
# 2019-01-15 18:06:10,365 trainer.supervised_trainer INFO     Progress: 82%, Train Error rate: 1.4538
# 2019-01-15 18:06:12,671 trainer.supervised_trainer INFO     Progress: 83%, Train Error rate: 1.5001
# 2019-01-15 18:06:15,345 trainer.supervised_trainer INFO     Progress: 84%, Train Error rate: 1.6065
# 2019-01-15 18:06:18,011 trainer.supervised_trainer INFO     Progress: 85%, Train Error rate: 1.5859
# 2019-01-15 18:06:20,468 trainer.supervised_trainer INFO     Progress: 86%, Train Error rate: 1.5770
# 2019-01-15 18:06:23,106 trainer.supervised_trainer INFO     Progress: 88%, Train Error rate: 1.5581
# 2019-01-15 18:06:25,450 trainer.supervised_trainer INFO     Progress: 89%, Train Error rate: 1.4520
# 2019-01-15 18:06:44,796 trainer.supervised_trainer INFO     Finished epoch 9: Train Error rate: 1.5497, Dev Error rate: 2.8134, Accuracy(Character): 0.6973, Accuracy(Word): 0.1262
# 2019-01-15 18:06:45,453 trainer.supervised_trainer INFO     Progress: 90%, Train Error rate: 1.5049
# 2019-01-15 18:06:48,066 trainer.supervised_trainer INFO     Progress: 91%, Train Error rate: 1.5609
# 2019-01-15 18:06:50,136 trainer.supervised_trainer INFO     Progress: 92%, Train Error rate: 1.4807
# 2019-01-15 18:06:52,369 trainer.supervised_trainer INFO     Progress: 93%, Train Error rate: 1.4728
# 2019-01-15 18:06:54,937 trainer.supervised_trainer INFO     Progress: 94%, Train Error rate: 1.5376
# 2019-01-15 18:06:57,678 trainer.supervised_trainer INFO     Progress: 96%, Train Error rate: 1.6172
# 2019-01-15 18:07:00,337 trainer.supervised_trainer INFO     Progress: 97%, Train Error rate: 1.5477
# 2019-01-15 18:07:02,809 trainer.supervised_trainer INFO     Progress: 98%, Train Error rate: 1.4882
# 2019-01-15 18:07:05,146 trainer.supervised_trainer INFO     Progress: 99%, Train Error rate: 1.4390
# 2019-01-15 18:07:24,025 trainer.supervised_trainer INFO     Finished epoch 10: Train Error rate: 1.5122, Dev Error rate: 3.0460, Accuracy(Character): 0.6973, Accuracy(Word): 0.1262

# %% [markdown]
# # Experimental results
#
# - units to error rate

# %%
plt.plot(hidden_sizes, error_rate)
plt.savefig('units_to_error_rate.png')

# %% [markdown]
# - units to accuracy

# %%
plt.clf()
plt.plot(hidden_sizes, accuracy)
plt.savefig('units_to_accuracy.png')

# %% [markdown]
# - save last model

# %%
torch.save(seq2seq.state_dict(), 'log/model_save.pth')
