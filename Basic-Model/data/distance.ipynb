# %% [markdown]
# # Import packages
#
# import useful packages for experiments

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lines = open('../data4/grammar_data.txt').read().strip().split('\n')

# %%
pairs = [[s for s in l.split('\t')] for l in lines]
distance = []
for pair in pairs:
    depth = []
    count = 0
    for i in pair[1].split(','):
        if(int(i) == 0):
            count = count + 1
            depth.append(count)
            count = 0
        else:
            count = count + 1
    depth.append(count)
    distance.append(max(depth))

# %% [markdown]
# # Experimental results
#
# - Include redundancy samples

# %%
plt.hist(distance, bins=10)
plt.savefig('distance.png')

# %% [markdown]
# - Remove redundancy samples and keep examples of length 100

# %%
plt.hist(distance, bins=10)
plt.savefig('distance.png')

# %% [markdown]
# - Include redundancy samples and keep examples of length 100

# %%
plt.hist(distance, bins=10)
plt.savefig('distance.png')

# %% [markdown]
# - Remove redundant samples

# %%
plt.hist(distance, bins=10)
plt.savefig('distance.png')
