# %% [markdown]
# # Set Parameter
# - Attention = Luong
# - Teacher Forcing Ratio = 0.5
# - Layer = 1
# - Batch size = 32
# - Drop out = 0.2
# - Hidden unit = [2, 50]
# - Distance = [0, 96]
# - Epochs = 100
# - N = 100
# - Data = 100K
# - Deduplication

# %% [markdown]
# # Import packages
#
# import useful packages for experiments

# %%
import os
import argparse
import logging
import sys

import torch
from torch.optim.lr_scheduler import StepLR
import torchtext

sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname(os.path.abspath(os.path.dirname('__file__'))))))

from trainer.supervised_trainer_without_eval import SupervisedTrainer_without_eval
from models.encoderRNN import EncoderRNN
from models.decoderRNN import DecoderRNN
from models.seq2seq import Seq2seq
from loss.loss import Perplexity
from optim.optim import Optimizer
from dataset import fields
from evaluator.evaluator import Evaluator

import matplotlib.pyplot as plt
# Out:
# /home/hyeontae/hyeontae/venv2/lib/python3.5/site-packages/torch/nn/_reduction.py:49: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# # Log format

# %%
log_level = 'info'
LOG_FORMAT = '%(asctime)s %(levelname)-6s %(message)s'
logging.basicConfig(format=LOG_FORMAT, level=getattr(logging, log_level.upper()))

# %% [markdown]
# # Data load

# %%
train_path = "../../data/bracket_dedup/K100/data_train.txt"

# %% [markdown]
# # Prepare dataset

# %%
src = fields.SourceField()
tgt = fields.TargetField()
max_len = 104
def len_filter(example):
    return len(example.src) <= max_len and len(example.tgt) <= max_len
train = torchtext.data.TabularDataset(
    path=train_path, format='tsv',
    fields=[('src', src), ('tgt', tgt)],
    filter_pred=len_filter
)
src.build_vocab(train)
tgt.build_vocab(train)
input_vocab = src.vocab
output_vocab = tgt.vocab

# %% [markdown]
# # Prepare loss

# %%
weight = torch.ones(len(tgt.vocab))
pad = tgt.vocab.stoi[tgt.pad_token]
loss = Perplexity(weight, pad)
if torch.cuda.is_available():
    loss.cuda()
# Out:
# /home/hyeontae/hyeontae/venv2/lib/python3.5/site-packages/torch/nn/_reduction.py:49: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# # Variable definition

# %%
optimizer = "Adam"
hidden_sizes = list(range(2, 51, 4))
distance_list = []
bidirectional = True
print(hidden_sizes)
evaluator = Evaluator(loss=loss, batch_size=32)
# Out:
# [2, 6, 10, 14, 18, 22, 26, 30, 34, 38, 42, 46, 50]

# %%
for i in hidden_sizes:
    hidden_size = i
    print("hidden size is : %d" % hidden_size)
    seq2seq = None
    encoder = EncoderRNN(len(src.vocab), max_len, hidden_size,
                         bidirectional=bidirectional, variable_lengths=True)
    decoder = DecoderRNN(len(tgt.vocab), max_len, hidden_size * 2 if bidirectional else hidden_size,
                         dropout_p=0.2, use_attention="Luong", bidirectional=bidirectional,
                         eos_id=tgt.eos_id, sos_id=tgt.sos_id)
    seq2seq = Seq2seq(encoder, decoder)
    if torch.cuda.is_available():
        seq2seq.cuda()

    for param in seq2seq.parameters():
        param.data.uniform_(-0.08, 0.08)
    
    distances = list(range(96, -1, -2))
    print(distances)
    for distance in distances:
        log_path = "../../log/pth/bracket_dedup_K100_hidden_" + str(hidden_size) + "_model_save.pth"
        seq2seq.load_state_dict(torch.load(log_path))
        seq2seq.eval()
        dev_path = "../../data/bracket_dedup/K100/dev_distance/data_test_distance_" + str(distance) + ".txt"
        dev = torchtext.data.TabularDataset(
              path=dev_path, format='tsv',
              fields=[('src', src), ('tgt', tgt)],
              filter_pred=len_filter)
        dev_loss, character_accuracy, sentence_accuracy = evaluator.evaluate(seq2seq, dev)
        print("Distance:%d, Dev Loss:%0.4f, Character Accuracy:%0.4f, Sentence Accuracy:%0.4f\n"
                    % (distance, dev_loss, character_accuracy, sentence_accuracy))
        check_path = "../../log/check_point/bracket_dedup_hidden_size_to_distance_0.99/hidden_size_" + str(hidden_size)
        with open(check_path, 'a') as f:
            f.write("Distance:%d, Dev Loss:%0.4f, Character Accuracy:%0.4f, Sentence Accuracy:%0.4f\n"
                    % (distance, dev_loss, character_accuracy, sentence_accuracy))
            
        if character_accuracy >= 0.99:
            distance_list.append(distance)
            break
        if distance == 0:
            distance_list.append(distance)
# Out:
# hidden size is : 2
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# /home/hyeontae/hyeontae/venv2/lib/python3.5/site-packages/torch/nn/modules/rnn.py:46: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# /home/hyeontae/hyeontae/venv2/lib/python3.5/site-packages/torch/nn/functional.py:1320: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Distance:96, Dev Loss:86.8922, Character Accuracy:0.1753, Sentence Accuracy:0.0000
#
# Distance:94, Dev Loss:85.1757, Character Accuracy:0.1764, Sentence Accuracy:0.0000
#
# Distance:92, Dev Loss:73.3644, Character Accuracy:0.1786, Sentence Accuracy:0.0000
#
# Distance:90, Dev Loss:72.4848, Character Accuracy:0.1719, Sentence Accuracy:0.0000
#
# Distance:88, Dev Loss:66.4828, Character Accuracy:0.1715, Sentence Accuracy:0.0000
#
# Distance:86, Dev Loss:61.5668, Character Accuracy:0.1674, Sentence Accuracy:0.0000
#
# Distance:84, Dev Loss:54.6836, Character Accuracy:0.1755, Sentence Accuracy:0.0000
#
# Distance:82, Dev Loss:53.0508, Character Accuracy:0.1710, Sentence Accuracy:0.0000
#
# Distance:80, Dev Loss:47.8900, Character Accuracy:0.1810, Sentence Accuracy:0.0000
#
# Distance:78, Dev Loss:48.5419, Character Accuracy:0.1773, Sentence Accuracy:0.0000
#
# Distance:76, Dev Loss:44.8631, Character Accuracy:0.1873, Sentence Accuracy:0.0000
#
# Distance:74, Dev Loss:44.4303, Character Accuracy:0.1831, Sentence Accuracy:0.0000
#
# Distance:72, Dev Loss:36.3255, Character Accuracy:0.2023, Sentence Accuracy:0.0000
#
# Distance:70, Dev Loss:39.4265, Character Accuracy:0.1962, Sentence Accuracy:0.0000
#
# Distance:68, Dev Loss:29.9941, Character Accuracy:0.2187, Sentence Accuracy:0.0000
#
# Distance:66, Dev Loss:32.5127, Character Accuracy:0.2097, Sentence Accuracy:0.0000
#
# Distance:64, Dev Loss:21.9324, Character Accuracy:0.2394, Sentence Accuracy:0.0000
#
# Distance:62, Dev Loss:26.0500, Character Accuracy:0.2261, Sentence Accuracy:0.0000
#
# Distance:60, Dev Loss:18.8038, Character Accuracy:0.2523, Sentence Accuracy:0.0000
#
# Distance:58, Dev Loss:18.5177, Character Accuracy:0.2559, Sentence Accuracy:0.0000
#
# Distance:56, Dev Loss:15.2384, Character Accuracy:0.2743, Sentence Accuracy:0.0000
#
# Distance:54, Dev Loss:16.7566, Character Accuracy:0.2674, Sentence Accuracy:0.0000
#
# Distance:52, Dev Loss:13.2434, Character Accuracy:0.2974, Sentence Accuracy:0.0000
#
# Distance:50, Dev Loss:14.1336, Character Accuracy:0.2876, Sentence Accuracy:0.0000
#
# Distance:48, Dev Loss:11.9625, Character Accuracy:0.3122, Sentence Accuracy:0.0000
#
# Distance:46, Dev Loss:12.1137, Character Accuracy:0.3109, Sentence Accuracy:0.0000
#
# Distance:44, Dev Loss:9.5793, Character Accuracy:0.3358, Sentence Accuracy:0.0000
#
# Distance:42, Dev Loss:10.6145, Character Accuracy:0.3287, Sentence Accuracy:0.0000
#
# Distance:40, Dev Loss:9.0200, Character Accuracy:0.3544, Sentence Accuracy:0.0000
#
# Distance:38, Dev Loss:9.4586, Character Accuracy:0.3450, Sentence Accuracy:0.0000
#
# Distance:36, Dev Loss:9.0782, Character Accuracy:0.3651, Sentence Accuracy:0.0000
#
# Distance:34, Dev Loss:8.9611, Character Accuracy:0.3606, Sentence Accuracy:0.0000
#
# Distance:32, Dev Loss:7.7263, Character Accuracy:0.3964, Sentence Accuracy:0.0000
#
# Distance:30, Dev Loss:7.8833, Character Accuracy:0.3908, Sentence Accuracy:0.0000
#
# Distance:28, Dev Loss:7.0903, Character Accuracy:0.4098, Sentence Accuracy:0.0000
#
# Distance:26, Dev Loss:6.9920, Character Accuracy:0.3924, Sentence Accuracy:0.0000
#
# Distance:24, Dev Loss:5.7649, Character Accuracy:0.4385, Sentence Accuracy:0.0000
#
# Distance:22, Dev Loss:6.0363, Character Accuracy:0.4190, Sentence Accuracy:0.0000
#
# Distance:20, Dev Loss:4.4907, Character Accuracy:0.4772, Sentence Accuracy:0.0000
#
# Distance:18, Dev Loss:4.6722, Character Accuracy:0.4715, Sentence Accuracy:0.0000
#
# Distance:16, Dev Loss:3.4415, Character Accuracy:0.5150, Sentence Accuracy:0.0000
#
# Distance:14, Dev Loss:3.5434, Character Accuracy:0.5194, Sentence Accuracy:0.0000
#
# Distance:12, Dev Loss:2.3594, Character Accuracy:0.6299, Sentence Accuracy:0.0000
#
# Distance:10, Dev Loss:2.3553, Character Accuracy:0.6495, Sentence Accuracy:0.0000
#
# Distance:8, Dev Loss:2.0922, Character Accuracy:0.6850, Sentence Accuracy:0.0000
#
# Distance:6, Dev Loss:1.9695, Character Accuracy:0.6897, Sentence Accuracy:0.0000
#
# Distance:4, Dev Loss:1.7482, Character Accuracy:0.7418, Sentence Accuracy:0.0000
#
# Distance:2, Dev Loss:1.5713, Character Accuracy:0.8113, Sentence Accuracy:0.0000
#
# Distance:0, Dev Loss:1.8934, Character Accuracy:0.7526, Sentence Accuracy:0.0000
#
# hidden size is : 6
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:12.0863, Character Accuracy:0.2542, Sentence Accuracy:0.0000
#
# Distance:94, Dev Loss:11.0438, Character Accuracy:0.2600, Sentence Accuracy:0.0000
#
# Distance:92, Dev Loss:10.5859, Character Accuracy:0.2712, Sentence Accuracy:0.0000
#
# Distance:90, Dev Loss:9.9449, Character Accuracy:0.2744, Sentence Accuracy:0.0000
#
# Distance:88, Dev Loss:9.6778, Character Accuracy:0.2845, Sentence Accuracy:0.0000
#
# Distance:86, Dev Loss:9.2264, Character Accuracy:0.2918, Sentence Accuracy:0.0000
#
# Distance:84, Dev Loss:8.8976, Character Accuracy:0.3018, Sentence Accuracy:0.0000
#
# Distance:82, Dev Loss:8.6343, Character Accuracy:0.3040, Sentence Accuracy:0.0000
#
# Distance:80, Dev Loss:8.4413, Character Accuracy:0.3151, Sentence Accuracy:0.0000
#
# Distance:78, Dev Loss:8.1615, Character Accuracy:0.3188, Sentence Accuracy:0.0000
#
# Distance:76, Dev Loss:8.0591, Character Accuracy:0.3272, Sentence Accuracy:0.0000
#
# Distance:74, Dev Loss:7.5680, Character Accuracy:0.3344, Sentence Accuracy:0.0000
#
# Distance:72, Dev Loss:7.6177, Character Accuracy:0.3414, Sentence Accuracy:0.0000
#
# Distance:70, Dev Loss:7.4412, Character Accuracy:0.3440, Sentence Accuracy:0.0000
#
# Distance:68, Dev Loss:7.5233, Character Accuracy:0.3526, Sentence Accuracy:0.0000
#
# Distance:66, Dev Loss:7.3800, Character Accuracy:0.3555, Sentence Accuracy:0.0000
#
# Distance:64, Dev Loss:7.2857, Character Accuracy:0.3675, Sentence Accuracy:0.0000
#
# Distance:62, Dev Loss:7.2987, Character Accuracy:0.3656, Sentence Accuracy:0.0000
#
# Distance:60, Dev Loss:7.1692, Character Accuracy:0.3792, Sentence Accuracy:0.0000
#
# Distance:58, Dev Loss:6.7900, Character Accuracy:0.3879, Sentence Accuracy:0.0000
#
# Distance:56, Dev Loss:6.8777, Character Accuracy:0.3986, Sentence Accuracy:0.0000
#
# Distance:54, Dev Loss:6.8756, Character Accuracy:0.4006, Sentence Accuracy:0.0000
#
# Distance:52, Dev Loss:6.2530, Character Accuracy:0.4168, Sentence Accuracy:0.0000
#
# Distance:50, Dev Loss:6.1255, Character Accuracy:0.4324, Sentence Accuracy:0.0000
#
# Distance:48, Dev Loss:5.9935, Character Accuracy:0.4385, Sentence Accuracy:0.0000
#
# Distance:46, Dev Loss:5.6861, Character Accuracy:0.4425, Sentence Accuracy:0.0000
#
# Distance:44, Dev Loss:5.4769, Character Accuracy:0.4670, Sentence Accuracy:0.0000
#
# Distance:42, Dev Loss:5.1161, Character Accuracy:0.4749, Sentence Accuracy:0.0000
#
# Distance:40, Dev Loss:5.0447, Character Accuracy:0.4872, Sentence Accuracy:0.0000
#
# Distance:38, Dev Loss:4.7700, Character Accuracy:0.4905, Sentence Accuracy:0.0000
#
# Distance:36, Dev Loss:4.5015, Character Accuracy:0.5108, Sentence Accuracy:0.0000
#
# Distance:34, Dev Loss:4.3229, Character Accuracy:0.5196, Sentence Accuracy:0.0000
#
# Distance:32, Dev Loss:3.9329, Character Accuracy:0.5587, Sentence Accuracy:0.0000
#
# Distance:30, Dev Loss:3.8548, Character Accuracy:0.5478, Sentence Accuracy:0.0000
#
# Distance:28, Dev Loss:3.3252, Character Accuracy:0.5995, Sentence Accuracy:0.0000
#
# Distance:26, Dev Loss:3.3608, Character Accuracy:0.5826, Sentence Accuracy:0.0000
#
# Distance:24, Dev Loss:2.7461, Character Accuracy:0.6539, Sentence Accuracy:0.0015
#
# Distance:22, Dev Loss:2.9829, Character Accuracy:0.6253, Sentence Accuracy:0.0030
#
# Distance:20, Dev Loss:1.9990, Character Accuracy:0.7449, Sentence Accuracy:0.0169
#
# Distance:18, Dev Loss:2.1357, Character Accuracy:0.7187, Sentence Accuracy:0.0100
#
# Distance:16, Dev Loss:1.5491, Character Accuracy:0.8308, Sentence Accuracy:0.0844
#
# Distance:14, Dev Loss:1.6619, Character Accuracy:0.8024, Sentence Accuracy:0.1124
#
# Distance:12, Dev Loss:1.2584, Character Accuracy:0.9093, Sentence Accuracy:0.4587
#
# Distance:10, Dev Loss:1.2867, Character Accuracy:0.8967, Sentence Accuracy:0.4061
#
# Distance:8, Dev Loss:1.1926, Character Accuracy:0.9314, Sentence Accuracy:0.6280
#
# Distance:6, Dev Loss:1.1782, Character Accuracy:0.9400, Sentence Accuracy:0.6379
#
# Distance:4, Dev Loss:1.1493, Character Accuracy:0.9459, Sentence Accuracy:0.6843
# Distance:2, Dev Loss:1.0928, Character Accuracy:0.9764, Sentence Accuracy:0.8645
#
# Distance:0, Dev Loss:1.3725, Character Accuracy:0.9021, Sentence Accuracy:0.3182
#
# hidden size is : 10
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.9266, Character Accuracy:0.7258, Sentence Accuracy:0.0000
#
# Distance:94, Dev Loss:1.9176, Character Accuracy:0.7276, Sentence Accuracy:0.0000
#
# Distance:92, Dev Loss:1.9036, Character Accuracy:0.7291, Sentence Accuracy:0.0000
#
# Distance:90, Dev Loss:1.8569, Character Accuracy:0.7395, Sentence Accuracy:0.0000
#
# Distance:88, Dev Loss:1.8519, Character Accuracy:0.7394, Sentence Accuracy:0.0000
#
# Distance:86, Dev Loss:1.8414, Character Accuracy:0.7430, Sentence Accuracy:0.0000
#
# Distance:84, Dev Loss:1.8039, Character Accuracy:0.7481, Sentence Accuracy:0.0000
#
# Distance:82, Dev Loss:1.7924, Character Accuracy:0.7526, Sentence Accuracy:0.0000
#
# Distance:80, Dev Loss:1.7748, Character Accuracy:0.7548, Sentence Accuracy:0.0000
#
# Distance:78, Dev Loss:1.7476, Character Accuracy:0.7605, Sentence Accuracy:0.0000
#
# Distance:76, Dev Loss:1.7200, Character Accuracy:0.7653, Sentence Accuracy:0.0000
#
# Distance:74, Dev Loss:1.7071, Character Accuracy:0.7697, Sentence Accuracy:0.0000
#
# Distance:72, Dev Loss:1.6897, Character Accuracy:0.7728, Sentence Accuracy:0.0000
#
# Distance:70, Dev Loss:1.6883, Character Accuracy:0.7742, Sentence Accuracy:0.0000
#
# Distance:68, Dev Loss:1.6572, Character Accuracy:0.7810, Sentence Accuracy:0.0000
#
# Distance:66, Dev Loss:1.6611, Character Accuracy:0.7822, Sentence Accuracy:0.0000
#
# Distance:64, Dev Loss:1.6408, Character Accuracy:0.7846, Sentence Accuracy:0.0000
#
# Distance:62, Dev Loss:1.6631, Character Accuracy:0.7801, Sentence Accuracy:0.0000
#
# Distance:60, Dev Loss:1.6360, Character Accuracy:0.7885, Sentence Accuracy:0.0000
#
# Distance:58, Dev Loss:1.6371, Character Accuracy:0.7885, Sentence Accuracy:0.0000
#
# Distance:56, Dev Loss:1.6106, Character Accuracy:0.7943, Sentence Accuracy:0.0000
#
# Distance:54, Dev Loss:1.6649, Character Accuracy:0.7842, Sentence Accuracy:0.0000
#
# Distance:52, Dev Loss:1.5962, Character Accuracy:0.7997, Sentence Accuracy:0.0000
#
# Distance:50, Dev Loss:1.6336, Character Accuracy:0.7899, Sentence Accuracy:0.0000
#
# Distance:48, Dev Loss:1.6057, Character Accuracy:0.7993, Sentence Accuracy:0.0000
#
# Distance:46, Dev Loss:1.6754, Character Accuracy:0.7815, Sentence Accuracy:0.0024
#
# Distance:44, Dev Loss:1.5895, Character Accuracy:0.8045, Sentence Accuracy:0.0000
#
# Distance:42, Dev Loss:1.6276, Character Accuracy:0.7946, Sentence Accuracy:0.0000
#
# Distance:40, Dev Loss:1.5755, Character Accuracy:0.8104, Sentence Accuracy:0.0018
#
# Distance:38, Dev Loss:1.6835, Character Accuracy:0.7820, Sentence Accuracy:0.0000
#
# Distance:36, Dev Loss:1.5382, Character Accuracy:0.8192, Sentence Accuracy:0.0086
#
# Distance:34, Dev Loss:1.6422, Character Accuracy:0.7958, Sentence Accuracy:0.0035
#
# Distance:32, Dev Loss:1.4562, Character Accuracy:0.8436, Sentence Accuracy:0.0451
#
# Distance:30, Dev Loss:1.5518, Character Accuracy:0.8112, Sentence Accuracy:0.0115
#
# Distance:28, Dev Loss:1.3481, Character Accuracy:0.8773, Sentence Accuracy:0.1338
#
# Distance:26, Dev Loss:1.5032, Character Accuracy:0.8278, Sentence Accuracy:0.0676
#
# Distance:24, Dev Loss:1.2640, Character Accuracy:0.9055, Sentence Accuracy:0.3013
#
# Distance:22, Dev Loss:1.3818, Character Accuracy:0.8645, Sentence Accuracy:0.1802
#
# Distance:20, Dev Loss:1.1692, Character Accuracy:0.9387, Sentence Accuracy:0.5581
#
# Distance:18, Dev Loss:1.2390, Character Accuracy:0.9128, Sentence Accuracy:0.4125
#
# Distance:16, Dev Loss:1.0799, Character Accuracy:0.9718, Sentence Accuracy:0.8244
#
# Distance:14, Dev Loss:1.1340, Character Accuracy:0.9519, Sentence Accuracy:0.6686
#
# Distance:12, Dev Loss:1.0439, Character Accuracy:0.9836, Sentence Accuracy:0.9091
#
# Distance:10, Dev Loss:1.0475, Character Accuracy:0.9839, Sentence Accuracy:0.8881
#
# Distance:8, Dev Loss:1.0243, Character Accuracy:0.9915, Sentence Accuracy:0.9470
#
# hidden size is : 14
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:2.2675, Character Accuracy:0.6472, Sentence Accuracy:0.0000
#
# Distance:94, Dev Loss:2.2035, Character Accuracy:0.6588, Sentence Accuracy:0.0000
#
# Distance:92, Dev Loss:2.2195, Character Accuracy:0.6574, Sentence Accuracy:0.0000
#
# Distance:90, Dev Loss:2.1461, Character Accuracy:0.6700, Sentence Accuracy:0.0000
#
# Distance:88, Dev Loss:2.1690, Character Accuracy:0.6659, Sentence Accuracy:0.0000
#
# Distance:86, Dev Loss:2.1130, Character Accuracy:0.6760, Sentence Accuracy:0.0000
#
# Distance:84, Dev Loss:2.1153, Character Accuracy:0.6779, Sentence Accuracy:0.0000
#
# Distance:82, Dev Loss:2.0645, Character Accuracy:0.6879, Sentence Accuracy:0.0000
#
# Distance:80, Dev Loss:2.0561, Character Accuracy:0.6886, Sentence Accuracy:0.0000
#
# Distance:78, Dev Loss:1.9984, Character Accuracy:0.6998, Sentence Accuracy:0.0000
#
# Distance:76, Dev Loss:1.9908, Character Accuracy:0.7038, Sentence Accuracy:0.0000
#
# Distance:74, Dev Loss:1.9475, Character Accuracy:0.7119, Sentence Accuracy:0.0000
#
# Distance:72, Dev Loss:1.9322, Character Accuracy:0.7170, Sentence Accuracy:0.0000
#
# Distance:70, Dev Loss:1.9081, Character Accuracy:0.7235, Sentence Accuracy:0.0000
#
# Distance:68, Dev Loss:1.8698, Character Accuracy:0.7316, Sentence Accuracy:0.0000
#
# Distance:66, Dev Loss:1.8547, Character Accuracy:0.7342, Sentence Accuracy:0.0000
#
# Distance:64, Dev Loss:1.8138, Character Accuracy:0.7446, Sentence Accuracy:0.0000
#
# Distance:62, Dev Loss:1.8500, Character Accuracy:0.7429, Sentence Accuracy:0.0000
#
# Distance:60, Dev Loss:1.7503, Character Accuracy:0.7614, Sentence Accuracy:0.0000
#
# Distance:58, Dev Loss:1.7613, Character Accuracy:0.7568, Sentence Accuracy:0.0000
#
# Distance:56, Dev Loss:1.7199, Character Accuracy:0.7732, Sentence Accuracy:0.0000
#
# Distance:54, Dev Loss:1.7654, Character Accuracy:0.7629, Sentence Accuracy:0.0000
#
# Distance:52, Dev Loss:1.6511, Character Accuracy:0.7889, Sentence Accuracy:0.0000
#
# Distance:50, Dev Loss:1.6809, Character Accuracy:0.7817, Sentence Accuracy:0.0000
#
# Distance:48, Dev Loss:1.6733, Character Accuracy:0.7976, Sentence Accuracy:0.0000
#
# Distance:46, Dev Loss:1.7032, Character Accuracy:0.7840, Sentence Accuracy:0.0000
#
# Distance:44, Dev Loss:1.5812, Character Accuracy:0.8124, Sentence Accuracy:0.0046
#
# Distance:42, Dev Loss:1.6632, Character Accuracy:0.7904, Sentence Accuracy:0.0000
#
# Distance:40, Dev Loss:1.5457, Character Accuracy:0.8256, Sentence Accuracy:0.0158
#
# Distance:38, Dev Loss:1.7192, Character Accuracy:0.7837, Sentence Accuracy:0.0068
#
# Distance:36, Dev Loss:1.4991, Character Accuracy:0.8394, Sentence Accuracy:0.0300
#
# Distance:34, Dev Loss:1.6955, Character Accuracy:0.7983, Sentence Accuracy:0.0140
#
# Distance:32, Dev Loss:1.4220, Character Accuracy:0.8612, Sentence Accuracy:0.0784
#
# Distance:30, Dev Loss:1.5320, Character Accuracy:0.8314, Sentence Accuracy:0.0268
#
# Distance:28, Dev Loss:1.3484, Character Accuracy:0.8889, Sentence Accuracy:0.1689
#
# Distance:26, Dev Loss:1.5226, Character Accuracy:0.8370, Sentence Accuracy:0.0890
#
# Distance:24, Dev Loss:1.2823, Character Accuracy:0.9098, Sentence Accuracy:0.2707
#
# Distance:22, Dev Loss:1.4478, Character Accuracy:0.8639, Sentence Accuracy:0.1712
#
# Distance:20, Dev Loss:1.1790, Character Accuracy:0.9434, Sentence Accuracy:0.4939
#
# Distance:18, Dev Loss:1.2505, Character Accuracy:0.9203, Sentence Accuracy:0.3525
#
# Distance:16, Dev Loss:1.0975, Character Accuracy:0.9684, Sentence Accuracy:0.7596
#
# Distance:14, Dev Loss:1.1404, Character Accuracy:0.9542, Sentence Accuracy:0.6529
#
# Distance:12, Dev Loss:1.0470, Character Accuracy:0.9841, Sentence Accuracy:0.9073
#
# Distance:10, Dev Loss:1.0523, Character Accuracy:0.9842, Sentence Accuracy:0.8628
#
# Distance:8, Dev Loss:1.1472, Character Accuracy:0.9662, Sentence Accuracy:0.6880
#
# Distance:6, Dev Loss:1.0453, Character Accuracy:0.9844, Sentence Accuracy:0.8669
#
# Distance:4, Dev Loss:1.1206, Character Accuracy:0.9924, Sentence Accuracy:0.9572
#
# hidden size is : 18
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.5043, Character Accuracy:0.8375, Sentence Accuracy:0.0000
#
# Distance:94, Dev Loss:1.4512, Character Accuracy:0.8510, Sentence Accuracy:0.0000
#
# Distance:92, Dev Loss:1.4280, Character Accuracy:0.8563, Sentence Accuracy:0.0000
#
# Distance:90, Dev Loss:1.3906, Character Accuracy:0.8666, Sentence Accuracy:0.0000
#
# Distance:88, Dev Loss:1.3678, Character Accuracy:0.8713, Sentence Accuracy:0.0000
#
# Distance:86, Dev Loss:1.3531, Character Accuracy:0.8786, Sentence Accuracy:0.0000
#
# Distance:84, Dev Loss:1.3038, Character Accuracy:0.8892, Sentence Accuracy:0.0000
#
# Distance:82, Dev Loss:1.3029, Character Accuracy:0.8911, Sentence Accuracy:0.0006
#
# Distance:80, Dev Loss:1.2628, Character Accuracy:0.9036, Sentence Accuracy:0.0017
#
# Distance:78, Dev Loss:1.2861, Character Accuracy:0.9029, Sentence Accuracy:0.0007
#
# Distance:76, Dev Loss:1.2257, Character Accuracy:0.9168, Sentence Accuracy:0.0102
#
# Distance:74, Dev Loss:1.2409, Character Accuracy:0.9164, Sentence Accuracy:0.0095
#
# Distance:72, Dev Loss:1.1953, Character Accuracy:0.9307, Sentence Accuracy:0.0231
#
# Distance:70, Dev Loss:1.2202, Character Accuracy:0.9278, Sentence Accuracy:0.0244
#
# Distance:68, Dev Loss:1.1602, Character Accuracy:0.9419, Sentence Accuracy:0.0560
#
# Distance:66, Dev Loss:1.1716, Character Accuracy:0.9423, Sentence Accuracy:0.0737
#
# Distance:64, Dev Loss:1.1281, Character Accuracy:0.9544, Sentence Accuracy:0.1349
#
# Distance:62, Dev Loss:1.1516, Character Accuracy:0.9481, Sentence Accuracy:0.1142
#
# Distance:60, Dev Loss:1.1168, Character Accuracy:0.9616, Sentence Accuracy:0.2322
#
# Distance:58, Dev Loss:1.1308, Character Accuracy:0.9596, Sentence Accuracy:0.2411
#
# Distance:56, Dev Loss:1.1093, Character Accuracy:0.9691, Sentence Accuracy:0.3594
#
# Distance:54, Dev Loss:1.1438, Character Accuracy:0.9593, Sentence Accuracy:0.3339
#
# Distance:52, Dev Loss:1.1200, Character Accuracy:0.9715, Sentence Accuracy:0.4808
#
# Distance:50, Dev Loss:1.1691, Character Accuracy:0.9626, Sentence Accuracy:0.3992
#
# Distance:48, Dev Loss:1.1156, Character Accuracy:0.9702, Sentence Accuracy:0.5012
#
# Distance:46, Dev Loss:1.2250, Character Accuracy:0.9570, Sentence Accuracy:0.4797
#
# Distance:44, Dev Loss:1.0872, Character Accuracy:0.9760, Sentence Accuracy:0.6055
#
# Distance:42, Dev Loss:1.2329, Character Accuracy:0.9592, Sentence Accuracy:0.5220
#
# Distance:40, Dev Loss:1.0931, Character Accuracy:0.9756, Sentence Accuracy:0.6380
#
# Distance:38, Dev Loss:1.2849, Character Accuracy:0.9528, Sentence Accuracy:0.5205
#
# Distance:36, Dev Loss:1.1476, Character Accuracy:0.9724, Sentence Accuracy:0.6831
#
# Distance:34, Dev Loss:1.1394, Character Accuracy:0.9684, Sentence Accuracy:0.6049
#
# Distance:32, Dev Loss:1.0868, Character Accuracy:0.9804, Sentence Accuracy:0.7647
#
# Distance:30, Dev Loss:1.2160, Character Accuracy:0.9672, Sentence Accuracy:0.6475
#
# Distance:28, Dev Loss:1.0918, Character Accuracy:0.9846, Sentence Accuracy:0.8328
#
# Distance:26, Dev Loss:1.1415, Character Accuracy:0.9727, Sentence Accuracy:0.7082
#
# Distance:24, Dev Loss:1.0984, Character Accuracy:0.9864, Sentence Accuracy:0.8952
#
# Distance:22, Dev Loss:1.0940, Character Accuracy:0.9820, Sentence Accuracy:0.7898
#
# Distance:20, Dev Loss:1.0163, Character Accuracy:0.9956, Sentence Accuracy:0.9528
#
# hidden size is : 22
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.1091, Character Accuracy:0.9643, Sentence Accuracy:0.3098
#
# Distance:94, Dev Loss:1.0643, Character Accuracy:0.9762, Sentence Accuracy:0.3901
#
# Distance:92, Dev Loss:1.0490, Character Accuracy:0.9828, Sentence Accuracy:0.5625
#
# Distance:90, Dev Loss:1.0390, Character Accuracy:0.9858, Sentence Accuracy:0.6350
#
# Distance:88, Dev Loss:1.0217, Character Accuracy:0.9923, Sentence Accuracy:0.8070
#
# hidden size is : 26
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.1418, Character Accuracy:0.9521, Sentence Accuracy:0.0705
#
# Distance:94, Dev Loss:1.1286, Character Accuracy:0.9577, Sentence Accuracy:0.0996
#
# Distance:92, Dev Loss:1.0856, Character Accuracy:0.9714, Sentence Accuracy:0.2823
#
# Distance:90, Dev Loss:1.0747, Character Accuracy:0.9753, Sentence Accuracy:0.3218
#
# Distance:88, Dev Loss:1.0448, Character Accuracy:0.9846, Sentence Accuracy:0.5191
#
# Distance:86, Dev Loss:1.0397, Character Accuracy:0.9867, Sentence Accuracy:0.5411
#
# Distance:84, Dev Loss:1.0242, Character Accuracy:0.9919, Sentence Accuracy:0.6593
#
# hidden size is : 30
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.0181, Character Accuracy:0.9945, Sentence Accuracy:0.8631
#
# hidden size is : 34
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.0290, Character Accuracy:0.9949, Sentence Accuracy:0.9474
#
# hidden size is : 38
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.0364, Character Accuracy:0.9935, Sentence Accuracy:0.7773
#
# hidden size is : 42
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.0000, Character Accuracy:1.0000, Sentence Accuracy:1.0000
#
# hidden size is : 46
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.0005, Character Accuracy:0.9999, Sentence Accuracy:0.9931
#
# hidden size is : 50
# [96, 94, 92, 90, 88, 86, 84, 82, 80, 78, 76, 74, 72, 70, 68, 66, 64, 62, 60, 58, 56, 54, 52, 50, 48, 46, 44, 42, 40, 38, 36, 34, 32, 30, 28, 26, 24, 22, 20, 18, 16, 14, 12, 10, 8, 6, 4, 2, 0]
# Distance:96, Dev Loss:1.0000, Character Accuracy:1.0000, Sentence Accuracy:1.0000

# %%
plt.figure(figsize=(15,10))
plt.plot(hidden_sizes, distance_list, LineWidth=3)
plt.xlabel('Hidden Size', fontsize=24)
plt.ylabel('Distance', fontsize=24)
plt.savefig('../../log/plot/bracket_dedup_hidden_size_to_distance_0.99/bracket_dedup_hidden_size_to_distance.png')

# %%
print(hidden_sizes)
print(distance_list)
