# %% [markdown]
# # Set Parameter
# - Attention = Luong
# - Teacher Forcing Ratio = 0.5
# - Layer = 1
# - Batch size = 32
# - Learning rate = 0.001
# - Hidden unit = 200
# - Epochs = 100
# - N = 100
# - Data Length = 100K
# - Data = [single_Ctype4_error_rate]
# - Deduplication
# - Random split

# %% [markdown]
# # Import packages
#
# import useful packages for experiments

# %%
import os
import argparse
import logging
import sys

import torch
from torch.optim.lr_scheduler import StepLR
import torchtext

sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname(os.path.abspath(os.path.dirname(os.path.abspath(os.path.dirname('__file__'))))))))

from trainer.supervised_trainer_correction import SupervisedTrainer_correction
from models.encoderRNN_lenemb_add import EncoderRNN_lenemb_add
from models.decoderRNN_lenemb_add import DecoderRNN_lenemb_add
from models.encoderRNN import EncoderRNN
from models.decoderRNN import DecoderRNN
from models.seq2seq import Seq2seq
from loss.loss import Perplexity
from optim.optim import Optimizer
from dataset import fields

import matplotlib.pyplot as plt
# Out:
# /home/hyeontae/hyeontae/venv/lib/python3.6/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# /home/hyeontae/hyeontae/venv/lib/python3.6/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# # Log format

# %%
log_level = 'info'
LOG_FORMAT = '%(asctime)s %(levelname)-6s %(message)s'
logging.basicConfig(format=LOG_FORMAT, level=getattr(logging, log_level.upper()))

# %%
data_path = ["single_Ctype4_error_rate"]
character_accuracy = []
sentence_accuracy = []
f1_score = []

# %% [markdown]
# # Prepare dataset

# %%
for i in data_path:
    print("data : %s" % i)
    train_path = "../../../data/palindrome_rand/correction_" + i + "/data_train.txt"
    dev_path = "../../../data/palindrome_rand/correction_" + i + "/data_test.txt"

    src = fields.SourceField()
    tgt = fields.TargetField()
    max_len = 104
    def len_filter(example):
        return len(example.src) <= max_len and len(example.tgt) <= max_len
    train = torchtext.data.TabularDataset(
        path=train_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    dev = torchtext.data.TabularDataset(
        path=dev_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    src.build_vocab(train)
    tgt.build_vocab(train)
    input_vocab = src.vocab
    output_vocab = tgt.vocab

    weight = torch.ones(len(tgt.vocab))
    pad = tgt.vocab.stoi[tgt.pad_token]
    loss = Perplexity(weight, pad)
    if torch.cuda.is_available():
        loss.cuda()
    
    optimizer = "Adam"
    hidden_size = 200
    bidirectional = False

    seq2seq = None
    encoder = EncoderRNN(len(src.vocab), max_len, hidden_size,
                         bidirectional=bidirectional, rnn_cell='lstm', variable_lengths=True)
    decoder = DecoderRNN(len(tgt.vocab), max_len, hidden_size * 2 if bidirectional else hidden_size,
                         dropout_p=0.2, use_attention="Luong", bidirectional=bidirectional,rnn_cell='lstm',
                         eos_id=tgt.eos_id, sos_id=tgt.sos_id)
    seq2seq = Seq2seq(encoder, decoder)
    if torch.cuda.is_available():
        seq2seq.cuda()

    for param in seq2seq.parameters():
        param.data.uniform_(-0.08, 0.08)

    # train
    t = SupervisedTrainer_correction(loss=loss, batch_size=32,
                          checkpoint_every=50,
                          print_every=100,
                          hidden_size=hidden_size,
                          path="palindrome_rand_correction_single_ctype4_error_rate",
                          file_name=i)

    seq2seq, ave_loss, character_accuracy_list, sentence_accuracy_list, f1_score_list = t.train(seq2seq, train,
                                                                             num_epochs=100, dev_data=dev,
                                                                             optimizer=optimizer,
                                                                             teacher_forcing_ratio=0.5)

    character_accuracy.append(character_accuracy_list)
    sentence_accuracy.append(sentence_accuracy_list)
    f1_score.append(f1_score_list)
# Out:
# data : single_Ctype4_error_rate
# /home/hyeontae/hyeontae/venv/lib/python3.6/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /home/hyeontae/hyeontae/venv/lib/python3.6/site-packages/torch/nn/modules/rnn.py:54: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# 2019-07-11 17:34:59,760 INFO   Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# /home/hyeontae/hyeontae/venv/lib/python3.6/site-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# ...

# %%
for i in data_path:
    print("data : %s" % i)
    train_path = "../../../data/palindrome_rand/correction_" + i + "/data_train.txt"
    dev_path = "../../../data/palindrome_rand/correction_" + i + "/data_test.txt"

    src = fields.SourceField()
    tgt = fields.TargetField()
    max_len = 104
    def len_filter(example):
        return len(example.src) <= max_len and len(example.tgt) <= max_len
    train = torchtext.data.TabularDataset(
        path=train_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    dev = torchtext.data.TabularDataset(
        path=dev_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    src.build_vocab(train)
    tgt.build_vocab(train)
    input_vocab = src.vocab
    output_vocab = tgt.vocab

    weight = torch.ones(len(tgt.vocab))
    pad = tgt.vocab.stoi[tgt.pad_token]
    loss = Perplexity(weight, pad)
    if torch.cuda.is_available():
        loss.cuda()
    
    optimizer = "Adam"
    hidden_size = 200
    bidirectional = False

    seq2seq = None
    encoder = EncoderRNN_lenemb_add(len(src.vocab), max_len, hidden_size,
                         bidirectional=bidirectional, rnn_cell='lstm', variable_lengths=True)
    decoder = DecoderRNN_lenemb_add(len(tgt.vocab), max_len, hidden_size * 2 if bidirectional else hidden_size,
                         dropout_p=0.2, use_attention="Luong", bidirectional=bidirectional,rnn_cell='lstm',
                         eos_id=tgt.eos_id, sos_id=tgt.sos_id)
    seq2seq = Seq2seq(encoder, decoder)
    if torch.cuda.is_available():
        seq2seq.cuda()

    for param in seq2seq.parameters():
        param.data.uniform_(-0.08, 0.08)

    # train
    t = SupervisedTrainer_correction(loss=loss, batch_size=32,
                          checkpoint_every=50,
                          print_every=100,
                          hidden_size=hidden_size,
                          path="palindrome_rand_correction_single_ctype4_error_rate_lenemb_add",
                          file_name=i)

    seq2seq, ave_loss, character_accuracy_list, sentence_accuracy_list, f1_score_list = t.train(seq2seq, train,
                                                                             num_epochs=100, dev_data=dev,
                                                                             optimizer=optimizer,
                                                                             teacher_forcing_ratio=0.5)

    character_accuracy.append(character_accuracy_list)
    sentence_accuracy.append(sentence_accuracy_list)
    f1_score.append(f1_score_list)
# Out:
# data : single_Ctype4_error_rate
# 2019-07-11 21:18:15,052 INFO   Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# 2019-07-11 21:20:49,136 INFO   Finished epoch 1: Train loss: 1.6837, Dev loss: 1.6060, Accuracy(character): 0.8735, Accuracy(sentence): 0.2826, F1 Score: 0.0013
# 2019-07-11 21:23:16,743 INFO   Finished epoch 2: Train loss: 1.5394, Dev loss: 1.5354, Accuracy(character): 0.8731, Accuracy(sentence): 0.2746, F1 Score: 0.0289
# 2019-07-11 21:25:35,057 INFO   Finished epoch 3: Train loss: 1.3926, Dev loss: 1.4366, Accuracy(character): 0.8739, Accuracy(sentence): 0.2892, F1 Score: 0.0235
# 2019-07-11 21:27:57,440 INFO   Finished epoch 4: Train loss: 1.3337, Dev loss: 1.3496, Accuracy(character): 0.8744, Accuracy(sentence): 0.2867, F1 Score: 0.0562
# ...

# %%
for i in data_path:
    print("data : %s" % i)
    train_path = "../../../data/palindrome_rand/correction_" + i + "/data_train.txt"
    dev_path = "../../../data/palindrome_rand/correction_" + i + "/data_test.txt"

    src = fields.SourceField()
    tgt = fields.TargetField()
    max_len = 104
    def len_filter(example):
        return len(example.src) <= max_len and len(example.tgt) <= max_len
    train = torchtext.data.TabularDataset(
        path=train_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    dev = torchtext.data.TabularDataset(
        path=dev_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    src.build_vocab(train)
    tgt.build_vocab(train)
    input_vocab = src.vocab
    output_vocab = tgt.vocab

    weight = torch.ones(len(tgt.vocab))
    pad = tgt.vocab.stoi[tgt.pad_token]
    loss = Perplexity(weight, pad)
    if torch.cuda.is_available():
        loss.cuda()
    
    optimizer = "Adam"
    hidden_size = 200
    bidirectional = False

    seq2seq = None
    encoder = EncoderRNN_lenemb_add(len(src.vocab), max_len, hidden_size,
                         bidirectional=bidirectional, rnn_cell='gru', variable_lengths=True)
    decoder = DecoderRNN_lenemb_add(len(tgt.vocab), max_len, hidden_size * 2 if bidirectional else hidden_size,
                         dropout_p=0.2, use_attention="Luong", bidirectional=bidirectional,rnn_cell='gru',
                         eos_id=tgt.eos_id, sos_id=tgt.sos_id)
    seq2seq = Seq2seq(encoder, decoder)
    if torch.cuda.is_available():
        seq2seq.cuda()

    for param in seq2seq.parameters():
        param.data.uniform_(-0.08, 0.08)

    # train
    t = SupervisedTrainer_correction(loss=loss, batch_size=32,
                          checkpoint_every=50,
                          print_every=100,
                          hidden_size=hidden_size,
                          path="gru_palindrome_rand_correction_single_ctype4_error_rate_lenemb_add",
                          file_name=i)

    seq2seq, ave_loss, character_accuracy_list, sentence_accuracy_list, f1_score_list = t.train(seq2seq, train,
                                                                             num_epochs=100, dev_data=dev,
                                                                             optimizer=optimizer,
                                                                             teacher_forcing_ratio=0.5)

    character_accuracy.append(character_accuracy_list)
    sentence_accuracy.append(sentence_accuracy_list)
    f1_score.append(f1_score_list)
# Out:
# data : single_Ctype4_error_rate
# 2019-07-12 01:50:55,612 INFO   Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# 2019-07-12 01:54:23,614 INFO   Finished epoch 1: Train loss: 1.6618, Dev loss: 1.6435, Accuracy(character): 0.8735, Accuracy(sentence): 0.2826, F1 Score: 0.0001
# 2019-07-12 01:58:01,553 INFO   Finished epoch 2: Train loss: 1.4970, Dev loss: 1.4862, Accuracy(character): 0.8739, Accuracy(sentence): 0.2890, F1 Score: 0.0381
# 2019-07-12 02:01:38,132 INFO   Finished epoch 3: Train loss: 1.3451, Dev loss: 1.3561, Accuracy(character): 0.8947, Accuracy(sentence): 0.3774, F1 Score: 0.3442
# 2019-07-12 02:05:06,574 INFO   Finished epoch 4: Train loss: 1.2361, Dev loss: 1.2725, Accuracy(character): 0.9070, Accuracy(sentence): 0.4225, F1 Score: 0.4951
# ...

# %%
epochs = list(range(1, 101, 1))
plt.figure(figsize=(15,7))
plt.plot(epochs[::3], sentence_accuracy[0][::3], '-', LineWidth=3, label="LSTM")
plt.plot(epochs[::3], sentence_accuracy[1][::3], '-s', LineWidth=3, label="LSTM LenEmb Add")
plt.plot(epochs[::3], sentence_accuracy[2][::3], '-o', LineWidth=3, label="GRU LenEmb Add")
plt.legend(loc="best", fontsize=12)
plt.xlabel('Epoch', fontsize=24)
plt.ylabel('Sentence Accuracy', fontsize=24)
plt.ylim([0, 1])
#plt.savefig('../../../log/plot/gru_palindrome_rand_correction_ctype4_lenemb_add_order_encoder_decoder/ctype_to_sentence_accuracy.png')
# Out:
# (0, 1)

# %%
plt.figure(figsize=(15,7))
plt.plot(epochs[::3], f1_score[0][::3], '-', LineWidth=3, label="LSTM")
plt.plot(epochs[::3], f1_score[1][::3], '-s', LineWidth=3, label="LSTM LenEmb Add")
plt.plot(epochs[::3], f1_score[2][::3], '-o', LineWidth=3, label="GRU LenEmb Add")
plt.legend(loc="best", fontsize=12)
plt.xlabel('Epoch', fontsize=24)
plt.ylabel('F1 Score', fontsize=24)
plt.ylim([0, 1])
#plt.savefig('../../../log/plot/gru_palindrome_rand_correction_ctype4_lenemb_add_order_encoder_decoder/ctype_to_f1_score.png')
# Out:
# (0, 1)

# %%
error_rate_list = []
for i in range(len(character_accuracy)):
    error_rate = []
    for j in character_accuracy[i]:
        error_rate.append(1 - j)
    error_rate_list.append(error_rate)

# %%
epochs = list(range(1, 101, 1))
plt.figure(figsize=(15,7))
plt.plot(epochs[::3], error_rate_list[0][::3], '-', LineWidth=3, label="LSTM")
plt.plot(epochs[::3], error_rate_list[1][::3], '-s', LineWidth=3, label="LSTM LenEmb Add")
plt.plot(epochs[::3], error_rate_list[2][::3], '-o', LineWidth=3, label="GRU LenEmb Add")
plt.legend(loc="best", fontsize=12)
plt.xlabel('Epoch', fontsize=24)
plt.ylabel('Error Rate', fontsize=24)
plt.yscale('log')
#plt.ylim([0, 1])
#plt.savefig('../../../log/plot/gru_palindrome_rand_correction_ctype4_lenemb_add_order_encoder_decoder/ctype_to_error_rate.png')

# %%
print(character_accuracy[0])
print(character_accuracy[1])
print(character_accuracy[2])
# Out:
# [0.8728935082480944, 0.8735270546288857, 0.8736579608999956, 0.8736924362156696, 0.8737269115313435, 0.8826620139979775, 0.8868360254058094, 0.8805000619556398, 0.8970267288621347, 0.8987100236230858, 0.899740285955256, 0.8994564891537659, 0.9005427114186243, 0.9032637631455878, 0.8940028939279476, 0.8934952573957047, 0.9058738942916872, 0.9033087309486407, 0.9090206412208859, 0.9099224954932269, 0.9106010096770712, 0.905157906938632, 0.9153076397299533, 0.9175760155728498, 0.9167875800926537, 0.919798424328181, 0.9164508212120122, 0.9121613924430108, 0.9208871448043201, 0.9196275466765795, 0.9218604479192898, 0.9212074154905088, 0.92027158554475, 0.9154205588798421, 0.9081392722810467, 0.9207227625020485, 0.9226094116612505, 0.923951450761255, 0.9239454550541812, 0.9235007734462125, 0.923543742680241, 0.9246309642296116, 0.9227248290224199, 0.9239299661442407, 0.925989991166325, 0.9253694354841934, 0.9257266796973367, 0.926308263283489, 0.9244990586739894, 0.9234558056431595, 0.9217
# ...

# %%
print(sentence_accuracy[0])
print(sentence_accuracy[1])
print(sentence_accuracy[2])
# Out:
# [0.27348, 0.28298, 0.28536, 0.28476, 0.28638, 0.30682, 0.34134, 0.36062, 0.39734, 0.42106, 0.4219, 0.41812, 0.43642, 0.44366, 0.40642, 0.43444, 0.4651, 0.46048, 0.48122, 0.48754, 0.49504, 0.49318, 0.51074, 0.52994, 0.5105, 0.53956, 0.49886, 0.5036, 0.53792, 0.53796, 0.54636, 0.54296, 0.5501, 0.48896, 0.53714, 0.54822, 0.5544, 0.5584, 0.56152, 0.5479, 0.56138, 0.56388, 0.5453, 0.56498, 0.56684, 0.56728, 0.56492, 0.57046, 0.56814, 0.56888, 0.56078, 0.5739, 0.57536, 0.57314, 0.57136, 0.56796, 0.57414, 0.57832, 0.5792, 0.57914, 0.57824, 0.57998, 0.5766, 0.58424, 0.57806, 0.56832, 0.56476, 0.58418, 0.58278, 0.58162, 0.5889, 0.58486, 0.58646, 0.58544, 0.58802, 0.59052, 0.58912, 0.58642, 0.59298, 0.59082, 0.5943, 0.58748, 0.59364, 0.59322, 0.57732, 0.58896, 0.59416, 0.59354, 0.59214, 0.59312, 0.5861, 0.59038, 0.58434, 0.59342, 0.59002, 0.59368, 0.59388, 0.59024, 0.5877, 0.59034]
# ...

# %%
print(f1_score[0])
print(f1_score[1])
print(f1_score[2])
# Out:
# [0.00110250978477434, 0.003428818591117315, 0.009469244535995269, 0.01843468267341725, 0.005876776505481451, 0.19649780172443262, 0.22779908302227678, 0.34218986774327514, 0.3186389369007922, 0.3527195998250671, 0.37808086724495393, 0.3710246248940731, 0.355315945407742, 0.4281247139486747, 0.43056148175580117, 0.4836108837871473, 0.51880528713559, 0.53191242569233, 0.47906907576771507, 0.47675923507733375, 0.5587276698765834, 0.5368288846346133, 0.5421793069202724, 0.5297990228894555, 0.5453711940534729, 0.5506130204937186, 0.5182128220559997, 0.583280234786378, 0.5834977705726094, 0.5422585287876805, 0.5869383250024426, 0.5900994727683556, 0.542903208254461, 0.6175147249474029, 0.6094568104479765, 0.6183293101624335, 0.6180414315403332, 0.6043337057341058, 0.618762535022948, 0.610842219461319, 0.580438233141347, 0.6393741041567129, 0.6497351291344385, 0.6320460536311611, 0.6384422668315732, 0.6533072919082922, 0.6288032150568501, 0.621943878792536, 0.6752994927124333, 0.66701970197
# ...
