# %% [markdown]
# # Set Parameter
# - Attention = True
# - Teacher Forcing Ratio = 0.5
# - Layer = 1
# - Batch size = 32
# - Learning rate = 0.001
# - Hidden unit = 200
# - Epochs = 100
# - N = 100
# - Data Length = 100K
# - Data = [single_Ctype4_error_rate]
# - Deduplication
# - Random split

# %% [markdown]
# # Import packages
#
# import useful packages for experiments

# %%
import os
import argparse
import logging
import sys
import json

import torch
from torch.optim.lr_scheduler import StepLR
import torchtext

os.chdir(os.path.dirname(os.path.abspath(os.path.dirname(os.path.abspath(os.path.dirname(os.path.abspath(os.path.dirname('__file__'))))))))

from models.trainer import Trainer
from models.seq2seq import Seq2seq
from loss.loss import Perplexity
from dataset import fields

import matplotlib.pyplot as plt
# Out:
# /home/hyeontae/hyeontae/venv1/lib/python3.6/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# /home/hyeontae/hyeontae/venv1/lib/python3.6/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# # Log format

# %%
log_level = 'info'
LOG_FORMAT = '%(asctime)s %(levelname)-6s %(message)s'
logging.basicConfig(format=LOG_FORMAT, level=getattr(logging, log_level.upper()))

# %%
data_path = ["single_Ctype4_error_rate_1", "single_Ctype4_error_rate_2", "single_Ctype4_error_rate_3",
             "single_Ctype4_error_rate_4", "single_Ctype4_error_rate_5"]
character_accuracy = []
sentence_accuracy = []
f1_score = []

# %% [markdown]
# # Prepare dataset

# %%
for i in data_path:
    print("data : %s" % i)
    train_path = "data/palindrome_rand/correction_" + i + "/data_train.txt"
    dev_path = "data/palindrome_rand/correction_" + i + "/data_test.txt"
    config_path = "models/config.json"
    max_len = 104
    src = fields.SourceField()
    tgt = fields.TargetField()
    def len_filter(example):
        return len(example.src) <= max_len and len(example.tgt) <= max_len
    train = torchtext.data.TabularDataset(
        path=train_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    dev = torchtext.data.TabularDataset(
        path=dev_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    src.build_vocab(train)
    tgt.build_vocab(train)
    input_vocab = src.vocab
    output_vocab = tgt.vocab

    weight = torch.ones(len(tgt.vocab))
    pad = tgt.vocab.stoi[tgt.pad_token]
    loss = Perplexity(weight, pad)
    if torch.cuda.is_available():
        loss.cuda()
        
    '''
    config = { "max_len": 102,
               "embedding_size": 5,
               "hidden_size": 200,
               "input_dropout_p": 0,
               "dropout_p": 0,
               "n_layers": 1,
               "bidirectional": False,
               "rnn_cell": "lstm",
               "embedding": None,
               "update_embedding": True,
               "get_context_vector": False,
               "use_attention": true,
               "position_embedding": None }
    '''

    optimizer = "Adam"
    seq2seq = None
    config_json = open(config_path).read()
    config = json.loads(config_json)
    config["max_len"] = max_len
    config["rnn_cell"] = "lstm"
    config["position_embedding"] = "length"
    
    print("Train_path : %s" % train_path)
    print("Dev_path = %s" % dev_path)
    print(json.dumps(config, indent=4))
    seq2seq = Seq2seq(config, len(src.vocab), len(tgt.vocab), tgt.sos_id, tgt.eos_id)
    
    if torch.cuda.is_available():
        seq2seq.cuda()

    for param in seq2seq.parameters():
        param.data.uniform_(-0.08, 0.08)

    # train
    t = Trainer(loss=loss, batch_size=32,
                checkpoint_every=50,
                print_every=100,
                hidden_size=config["hidden_size"],
                path="palindrome_rand_multi_error",
                file_name=i + "_" + config["rnn_cell"])

    seq2seq, ave_loss, character_accuracy_list, sentence_accuracy_list, f1_score_list = t.train(seq2seq, train,
                                                                             num_epochs=100, dev_data=dev,
                                                                             optimizer=optimizer,
                                                                             teacher_forcing_ratio=0.5)

    character_accuracy.append(character_accuracy_list)
    sentence_accuracy.append(sentence_accuracy_list)
    f1_score.append(f1_score_list)
# Out:
# data : single_Ctype4_error_rate_1
# /home/hyeontae/hyeontae/venv1/lib/python3.6/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 2019-08-15 03:59:01,299 INFO   Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# ), Scheduler: None
# Train_path : data/palindrome_rand/correction_single_Ctype4_error_rate_1/data_train.txt
# Dev_path = data/palindrome_rand/correction_single_Ctype4_error_rate_1/data_test.txt
# {
#     "max_len": 104,
#     "embedding_size": 5,
#     "hidden_size": 200,
#     "input_dropout_p": 0,
#     "dropout_p": 0,
#     "n_layers": 1,
#     "bidirectional": false,
#     "rnn_cell": "lstm",
#     "variable_lengths": false,
#     "embedding": null,
#     "update_embedding": true,
#     "get_context_vector": false,
#     "use_attention": true,
# ...

# %%
for i in data_path:
    print("data : %s" % i)
    train_path = "data/palindrome_rand/correction_" + i + "/data_train.txt"
    dev_path = "data/palindrome_rand/correction_" + i + "/data_test.txt"
    config_path = "models/config.json"
    max_len = 104
    src = fields.SourceField()
    tgt = fields.TargetField()
    def len_filter(example):
        return len(example.src) <= max_len and len(example.tgt) <= max_len
    train = torchtext.data.TabularDataset(
        path=train_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    dev = torchtext.data.TabularDataset(
        path=dev_path, format='tsv',
        fields=[('src', src), ('tgt', tgt)],
        filter_pred=len_filter
    )
    src.build_vocab(train)
    tgt.build_vocab(train)
    input_vocab = src.vocab
    output_vocab = tgt.vocab

    weight = torch.ones(len(tgt.vocab))
    pad = tgt.vocab.stoi[tgt.pad_token]
    loss = Perplexity(weight, pad)
    if torch.cuda.is_available():
        loss.cuda()
        
    '''
    config = { "max_len": 102,
               "embedding_size": 5,
               "hidden_size": 200,
               "input_dropout_p": 0,
               "dropout_p": 0,
               "n_layers": 1,
               "bidirectional": False,
               "rnn_cell": "lstm",
               "embedding": None,
               "update_embedding": True,
               "get_context_vector": False,
               "use_attention": true,
               "position_embedding": None }
    '''

    optimizer = "Adam"
    seq2seq = None
    config_json = open(config_path).read()
    config = json.loads(config_json)
    config["max_len"] = max_len
    config["rnn_cell"] = "gru"
    config["position_embedding"] = "length"
    
    print("Train_path : %s" % train_path)
    print("Dev_path = %s" % dev_path)
    print(json.dumps(config, indent=4))
    seq2seq = Seq2seq(config, len(src.vocab), len(tgt.vocab), tgt.sos_id, tgt.eos_id)
    
    if torch.cuda.is_available():
        seq2seq.cuda()

    for param in seq2seq.parameters():
        param.data.uniform_(-0.08, 0.08)

    # train
    t = Trainer(loss=loss, batch_size=32,
                checkpoint_every=50,
                print_every=100,
                hidden_size=config["hidden_size"],
                path="palindrome_rand_multi_error",
                file_name=i + "_" + config["rnn_cell"])

    seq2seq, ave_loss, character_accuracy_list, sentence_accuracy_list, f1_score_list = t.train(seq2seq, train,
                                                                             num_epochs=100, dev_data=dev,
                                                                             optimizer=optimizer,
                                                                             teacher_forcing_ratio=0.5)

    character_accuracy.append(character_accuracy_list)
    sentence_accuracy.append(sentence_accuracy_list)
    f1_score.append(f1_score_list)
# Out:
# data : single_Ctype
836275793561205, 0.7931901227584383, 0.7836390425522529, 0.803218839518891, 0.8063646361797993, 0.7991298104786042, 0.8053555891277906, 0.8126167086141105, 0.8174921118871201, 0.8126422601775755, 0.8194066007334148, 0.823352282821105, 0.8235081230663306, 0.8250900883063398, 0.8249693676415748, 0.8073584143624576, 0.8294352738271897, 0.8291273787073548, 0.8331961110624506, 0.8331807890553494, 0.8346704052755927, 0.83234761513547, 0.8370301512295469, 0.8359318417389117, 0.8374359636661071, 0.8393351919919678, 0.8379910721921017, 0.834201213346815, 0.8379291665591869, 0.8406463712000138, 0.8365915271548844, 0.8419073238012833, 0.8412047245440405, 0.8404111955770559, 0.8398991772969793, 0.8407929164284105, 0.8375953210070445, 0.8422360891742834, 0.8392223988262624, 0.8411113550937109, 0.832720314130921, 0.8430030753349534, 0.8406546736140165, 0.8366251214527424, 0.8389508389508389, 0.8409676501925027, 0.8421097781190084, 0.8371920339732519, 0.8363688500740079, 0.8347158898579553, 0.8218482524418467, 0.8375897659420505, 0.837137766422376, 0.8345670181975448, 0.8389337744131307, 0.8320262417370166, 0.8337891192866984, 0.8300377859901175, 0.8358886325388356, 0.8316351245260328, 0.8326776979914663, 0.8338723390067849, 0.827509816077702, 0.8276389321699388, 0.8287426539459398, 0.8280480142852419, 0.8268916172315216, 0.8202497203247102, 0.8291018415374994, 0.8287676646656765, 0.8187188723056852, 0.8268822304250099, 0.8272131822863028, 0.8265220367887904, 0.8286216940171582, 0.8216473513318994, 0.8188667762156899, 0.8145828385574954, 0.8205913208178727, 0.8193682463896018])

# %%
epochs = list(range(1, 101, 1))
plt.figure(figsize=(15,7))
plt.plot(epochs[::3], sentence_accuracy[0][::3], '-', LineWidth=3, label="GRU Error 1")
plt.plot(epochs[::3], sentence_accuracy[1][::3], '-^', LineWidth=3, label="GRU Error 2")
plt.plot(epochs[::3], sentence_accuracy[2][::3], '-o', LineWidth=3, label="GRU Error 3")
plt.plot(epochs[::3], sentence_accuracy[3][::3], '-x', LineWidth=3, label="GRU Error 4")
plt.plot(epochs[::3], sentence_accuracy[4][::3], '-s', LineWidth=3, label="GRU Error 5")
plt.plot(epochs[::3], sentence_accuracy[5][::3], '--', LineWidth=3, label="LSTM Error 1")
plt.plot(epochs[::3], sentence_accuracy[6][::3], '--^', LineWidth=3, label="LSTM Error 2")
plt.plot(epochs[::3], sentence_accuracy[7][::3], '--o', LineWidth=3, label="LSTM Error 3")
plt.plot(epochs[::3], sentence_accuracy[8][::3], '--x', LineWidth=3, label="LSTM Error 4")
plt.plot(epochs[::3], sentence_accuracy[9][::3], '--s', LineWidth=3, label="LSTM Error 5")
plt.legend(loc="best", fontsize=12)
plt.xlabel('Epoch', fontsize=24)
plt.ylabel('Sentence Accuracy', fontsize=24)
plt.ylim([0, 1])
#plt.savefig('../../../log/plot/gru_palindrome_rand_correction_ctype4_lenemb_add_order_encoder_decoder/ctype_to_sentence_accuracy.png')
# Out:
# (0, 1)

# %%
plt.figure(figsize=(15,7))
plt.plot(epochs[::3], f1_score[0][::3], '-', LineWidth=3, label="GRU Error 1")
plt.plot(epochs[::3], f1_score[1][::3], '-^', LineWidth=3, label="GRU Error 2")
plt.plot(epochs[::3], f1_score[2][::3], '-o', LineWidth=3, label="GRU Error 3")
plt.plot(epochs[::3], f1_score[3][::3], '-x', LineWidth=3, label="GRU Error 4")
plt.plot(epochs[::3], f1_score[4][::3], '-s', LineWidth=3, label="GRU Error 5")
plt.plot(epochs[::3], f1_score[5][::3], '--', LineWidth=3, label="LSTM Error 1")
plt.plot(epochs[::3], f1_score[6][::3], '--^', LineWidth=3, label="LSTM Error 2")
plt.plot(epochs[::3], f1_score[7][::3], '--o', LineWidth=3, label="LSTM Error 3")
plt.plot(epochs[::3], f1_score[8][::3], '--x', LineWidth=3, label="LSTM Error 4")
plt.plot(epochs[::3], f1_score[9][::3], '--s', LineWidth=3, label="LSTM Error 5")
plt.legend(loc="best", fontsize=12)
plt.xlabel('Epoch', fontsize=24)
plt.ylabel('F1 Score', fontsize=24)
plt.ylim([0, 1])
#plt.savefig('../../../log/plot/gru_palindrome_rand_correction_ctype4_lenemb_add_order_encoder_decoder/ctype_to_f1_score.png')
# Out:
# (0, 1)

# %%
error_rate_list = []
for i in range(len(character_accuracy)):
    error_rate = []
    for j in character_accuracy[i]:
        error_rate.append(1 - j)
    error_rate_list.append(error_rate)

# %%
epochs = list(range(1, 101, 1))
plt.figure(figsize=(15,7))
plt.plot(epochs[::3], error_rate_list[0][::3], '-', LineWidth=3, label="GRU Error 1")
plt.plot(epochs[::3], error_rate_list[1][::3], '-^', LineWidth=3, label="GRU Error 2")
plt.plot(epochs[::3], error_rate_list[2][::3], '-o', LineWidth=3, label="GRU Error 3")
plt.plot(epochs[::3], error_rate_list[3][::3], '-x', LineWidth=3, label="GRU Error 4")
plt.plot(epochs[::3], error_rate_list[4][::3], '-s', LineWidth=3, label="GRU Error 5")
plt.plot(epochs[::3], error_rate_list[5][::3], '--', LineWidth=3, label="LSTM Error 1")
plt.plot(epochs[::3], error_rate_list[6][::3], '--^', LineWidth=3, label="LSTM Error 2")
plt.plot(epochs[::3], error_rate_list[7][::3], '--o', LineWidth=3, label="LSTM Error 3")
plt.plot(epochs[::3], error_rate_list[8][::3], '--x', LineWidth=3, label="LSTM Error 4")
plt.plot(epochs[::3], error_rate_list[9][::3], '--s', LineWidth=3, label="LSTM Error 5")
plt.legend(loc="best", fontsize=12)
plt.xlabel('Epoch', fontsize=24)
plt.ylabel('Error Rate', fontsize=24)
plt.yscale('log')
#plt.ylim([0, 1])
#plt.savefig('../../../log/plot/gru_palindrome_rand_correction_ctype4_lenemb_add_order_encoder_decoder/ctype_to_error_rate.png')

# %%
print(len(character_accuracy))
for i in character_accuracy:
    print(i)
# Out:
# 10
# ...

# %%
print(len(sentence_accuracy))
for i in sentence_accuracy:
    print(i)
# Out:
# 10
# [0.29326, 0.29366, 0.3457, 0.41752, 0.46338, 0.49018, 0.51708, 0.56876, 0.63356, 0.65246, 0.66396, 0.62762, 0.72076, 0.67616, 0.74376, 0.73498, 0.74994, 0.75498, 0.75582, 0.78734, 0.7563, 0.75142, 0.72828, 0.76796, 0.79544, 0.76492, 0.78874, 0.752, 0.79628, 0.79706, 0.78938, 0.79494, 0.80112, 0.8237, 0.80758, 0.82428, 0.81562, 0.82016, 0.83104, 0.81444, 0.8256, 0.8311, 0.8196, 0.84242, 0.821, 0.77994, 0.84472, 0.83918, 0.81912, 0.86252, 0.78392, 0.84668, 0.79982, 0.8496, 0.84296, 0.8063, 0.83426, 0.85738, 0.85254, 0.83904, 0.84562, 0.84638, 0.8639, 0.83426, 0.86398, 0.8585, 0.8471, 0.86976, 0.85474, 0.86782, 0.85494, 0.86926, 0.85808, 0.85302, 0.8727, 0.87344, 0.83764, 0.86974, 0.87442, 0.85922, 0.86364, 0.86402, 0.88108, 0.88462, 0.8815, 0.8706, 0.86404, 0.86242, 0.87462, 0.88098, 0.86894, 0.86672, 0.82328, 0.88016, 0.8834, 0.88764, 0.87878, 0.88404, 0.88982, 0.86436]
# ...

# %%
print(len(f1_score))
for i in f1_score:
    print(i)
# Out:
# 10
# ...

# %%
print(len(error_rate_list))
for i in error_rate_list:
    print(i)
# Out:
# 10
# ...
